# %%
import pandas as pd
import glob

# 步骤1：读取所有文件内容并合并
file_paths = glob.glob("/data1/yzf/fragmlm/output/small_valid_answer_*")  # 修改为你的文件路径
file_paths
# Out:
# ['/data1/yzf/fragmlm/output/small_valid_answer_2',
#  '/data1/yzf/fragmlm/output/small_valid_answer_3',
#  '/data1/yzf/fragmlm/output/small_valid_answer_9',
#  '/data1/yzf/fragmlm/output/small_valid_answer_0',
#  '/data1/yzf/fragmlm/output/small_valid_answer_7',
#  '/data1/yzf/fragmlm/output/small_valid_answer_5',
#  '/data1/yzf/fragmlm/output/small_valid_answer_1',
#  '/data1/yzf/fragmlm/output/small_valid_answer_8',
#  '/data1/yzf/fragmlm/output/small_valid_answer_6',
#  '/data1/yzf/fragmlm/output/small_valid_answer_4']

# %%
all_smiles = []

for file_path in file_paths:
    with open(file_path, "r") as f:
        lines = f.readlines()
        all_smiles.extend([line.strip() for line in lines if line.strip() != ""])

# 步骤2：创建DataFrame
df = pd.DataFrame({"SMILES": all_smiles})

# 可选：去重（如果需要）
df = df.drop_duplicates(subset=["SMILES"])

# 查看结果
print(f"Total SMILES: {len(df)}")
print(df.head())
# Out:
# Total SMILES: 9805
#                                     SMILES
# 0  COc1cccc(OCC(=O)c2cccn(C(F)(F)F)c2=O)c1
# 1             CNc1cccc(CI)c1[Si](Cl)(Cl)Cl
# 2     Cc1ccc(-c2ccc(CNCCC3CCCC3)o2)c(Cl)c1
# 3             CCCCN=C(O)C1CCCN(Cc2cccs2)C1
# 4   Cc1noc(C)c1CCN=C(O)N1CCCC1CC(O)c1cccs1

# %%
small_results = df["SMILES"].to_list()
small_results
# Out:
# ['COc1cccc(OCC(=O)c2cccn(C(F)(F)F)c2=O)c1',
#  'CNc1cccc(CI)c1[Si](Cl)(Cl)Cl',
#  'Cc1ccc(-c2ccc(CNCCC3CCCC3)o2)c(Cl)c1',
#  'CCCCN=C(O)C1CCCN(Cc2cccs2)C1',
#  'Cc1noc(C)c1CCN=C(O)N1CCCC1CC(O)c1cccs1',
#  'COc1ccc(F)c(CNCCOCc2ccccc2)c1',
#  'CCNCC(=O)c1cc2c(cn1)CN(C(O)(C(O)=NC)c1cccnc1)C2',
#  'Cc1cccnc1C=CC([O-])=NS(=O)(=O)c1ccc(F)c(F)c1',
#  'COc1ccc(Cl)c(N2C(=O)CC3(CCCN(C(c4ccc(F)cc4)(c4ccccn4)c4ccccn4)C3=O)C2=O)c1',
#  'O=c1nc(O)ccn1CC(O)=Nc1ccccc1COc1ccccc1',
#  'O=C(Nc1ccc(Cl)cc1)n1c(=O)n(Cc2ccccc2)c2ccccc21',
#  'OC1CCCCC1c1nnc2CN(CCl)CCn21',
#  'Cc1c(C)c(OCCCCCCl)c(C)cc1',
#  'CC(C)(C)c1cc2c(c[n+]1O)CCc1c-2[nH][nH]c1=N',
#  'CC(C)c1c(Br)cnn1CC(O)C1COc2ccccc2O1',
#  'C[N+](C)(C)CCOC(=O)C(C#N)=Cc1ccc(I)c(O)c1',
#  'CC1=C(C(=O)O)S(=O)C(C)(C)C2=C1C(=O)CC(C(=O)O)(C1CCCCC1)C2',
#  'CC(C)CC(=O)N=c1ncn(N(C)CCOc2ccc(Cl)cc2)[nH]1',
#  'CC1CC1N=C(O)Nc1cccc(S(=O)(=O)C(F)F)c1',
#  'O=C(c1ccc2OCCCc2c1)N1CCN(CC2CCCO2)CC1',
#  'CCc1ccccc1OCCOc1c(Br)cc(C=O)cc1Br',
#  'CCOC(=O)C1(Cc2cccc(F)c2)CCCN(S(=O)(=O)c2ccc(F)cc2)C1',
#  'CCOc1cc2c(cc1N=C(O)c1cc3ccccc3c(N=C(C)O)c1OC)OCCO2',
#  'O=C(OC(c1ccccc1)c1ccccc1)c1ccc(N2C(=O)C3C4C=CC(CC4)C3C2=O)cc1',
#  'CCn1nc(C)c(C(O)=Nc2nc(C)c(C)s2)c1C',
#  'Cc1ccccc1C1(N2CC(C(O)=NCC(C)(C)c3ccc4OCOc4c3)CC2=O)CC1',
#  'Cc1cc(O)nc2nnc(CCC(=O)N3CC4CCNCC4C3)n12',
#  'COc1ccc2C3=C(C=CC3(OC)OC)CCc2c1',
#  'CCC(C)N=C(O)c1c2ccccc2nc(C(=O)O)c1',
#  'COc1ccc(CN(Cc2ccc(OC)cc2)c2ccc3ccccc3c2)cc1',
#  'COCCC(=O)N1CCN(S(=O)(=O)c2cccs2)C(C(=N)O)C1',
#  'C[n+]1c(-c2cnc(-c3ccccn3)nn2)ccc2c1C(C)(C)c1cc(-c3cnc(-c4cnc(-c5ccccn5)nn4)nn3)ccc-21',
#  'CN(C)c1ccc(C2=NOC(CN(CC3CC3)C(=O)c3cccc(F)c3)C2)cc1',
#  'COc1ccc(C(O)=Nc2ccc3nccnc3c2Br)cc1OCc1cccnc1',
#  'COCCN1CCCC2(CCN(C(=O)c3c(C(C)C)[nH]cc3)C2)C1',
#  'COC(=O)C(C)(C)NCN=C(O)Cc1ccccc1Cl',
#  'COc1cc(Cl)c(C(=S)c2ccc(F)cc2)cc1F',
#  'CCOC(=O)C1c2ccc(Br)cc2N(C)c2cc(Br)cnc21',
#  'COc1ccc(N(CC(O)=Nc2ccccc2C)C(C)=O)c(OC)c1',
#  'CCOc1ccc2nc(O)n(CC(C)(C)OC)c2c1',
#  'CC(=O)N(CN=C(O)Cc1ccc2OCOc2c1)c1ccccc1',
#  'Cc1cccc2ncc(-c3nn(C(C)c4cccnc4)c(=O)c4cc5c(ccs5)n34)n12',
#  'CN(Cc1ccc(O)cc1)C(=O)C(F)(F)c1ccccc1F',
#  'Bc1cc(F)c(OCc2ccc(-c3ccccc3)cc2)c(F)c1',
#  'CCOc1cccc2c1[nH]c(=N)n2C1CCN(c2ccc(S(=O)(=O)OC)cc2Cl)CC1',
#  'CN1C(=O)C(=O)C2C1CCN2C(=O)c1cc2c(cn1)[nH]c(N1CCC(F)C1)c2',
#  'COc1cccc(COCC(O)=Nc2cc(OC)ccc2N=C(C)O)c1',
#  'COC(=O)c1ccc(C(O)CC(=O)O)c(F)c1',
#  'CCN=C(O)C1CCN(Cc2cccn2-c2nnc(-c3ccccc3)o2)CC1',
#  'CN(CCC1CCOCC1)C(=O)CCCN=C(O)C1CC1',
#  'CC(CNC1CC1C)c1ccco1',
#  'CC(C)COc1cccc(CN=C(O)c2c(C(F)(F)F)n(C(C)(C)C)nc2)c1',
#  'CCCCc1cccc(C(=O)Nc2ccc(S(=O)(=O)NN=S(C)(=O)c3ccc(OC)cc3F)cc2N)c1',
#  'CS(=O)(=O)C(CN=C(O)C1CCOC1)c1ccccc1',
#  'CC(C)N(CCO)C(=O)c1cccs1',
#  'CC(C)c1c[nH+]c(N=C(O)N2CCC(CN(C)C)CC2)s1',
#  'COc1cc(OC)c(OC)cc1C=c1sc2=NC(C)=C(C(O)=Nc3ccccc3)C(c3ccc(F)cc3)n2c1=O',
#  'COc1ccc(NCC(=O)N2CCN(c3nccc[nH+]3)CC2)cc1',
#  'COc1c(OCCCC(O)=Nc2ccccc2)c(OC)ccc1',
#  'CCC1Cc2c([nH]c3ccccc23)C(c2cc(O)c(O)c(O)c2)N1C(=O)c1ccccc1Br',
#  'CC(C)c1ccc(OCCc2nn(-c3ccc4OCCc4c3)nn2)cc1',
#  'CCCNCc1ccccc1CNS(=O)(=O)NC(C)(C)C',
#  'CCCCCC1C(=O)C(OC)=C[NH+](C)C1C(=O)c1ccc(C)cc1',
#  'CCCCCc1cc(N(C)C)c2CC3CC4=C(C(=O)c5ccc(F)cc5)C(=O)C(C(=O)OC)=C(O)C4(O)C(=O)C3=C(O)c2c1O',
#  'COc1ccc(CCCN2CCN(CC(=O)Nc3ccc(C)cc3)CC2)c(OC)c1',
#  'CCC(C)C1NNCC1C',
#  'COC(=O)Nc1ccc(CNC(C)c2c(C)oc(C)n2)cc1',
#  'CCS(=O)C1CCCC(NC(=NC)NCN=C(O)Cc2cccc(OC(F)(F)C(F)F)c2)C1',
#  'CCCCN(C)C(=O)C1CCN(CN=C(O)Cc2ccccc2OC)CC1',
#  'Cc1c(C(c2ccccc2)c2ccccc2)c(C(O)=Nc2cc(OCc3ccncc3)ccc2)ccc1',
#  'CCOc1ccccc1C(C)N=C(O)C1CC(=O)N(C(C)c2cccc3ccccc23)C1',
#  'Cc1cnc(-c2cccc(C3OCCO3)c2)o1',
#  'CCOC(=O)CC(c1ccc(F)c(F)c1)C1CCN(Cc2cccnc2OC(F)F)CC1',
#  'CCOc1ccc(Br)cc1S(=O)(=O)n1ccc(=N)nc1C(C)C',
#  'CCCCOCC(=O)N(c1ccc(Cl)nn1)c1nc(C)cs1',
#  'CC(=O)Oc1ccc([N+](=O)[O-])c(C2CC2)c1CN1CC(C)N(C)CC1C',
#  'CC(C)(C)OC(=O)C1CSCN1C(=O)N1CCCC(C(O)=[NH+]c2cccc(Cl)c2)C1',
#  'CC(O)=Nc1ccccc1N1C(=O)C2CC(C)=C3B(O)OC(c4ccccc4O)CC3C2C1=O',
#  'CN(C)c1ccc(C2C3C(=NN2c2ccccc2)c2ccccc2[NH2+]C2CCCCC23)cc1',
#  'CC(C)CCN1CCCN(Cc2cnc(-c3ccccc3)s2)CC1',
#  'COC(=O)c1c(NC=C2C=CC=C(OC)C2=O)c(N)c(C#N)s1',
#  'COc1ccc([N+](=O)[O-])cc1C(=O)N1CCCC(C(O)=Nc2ccccc2Br)C1',
#  'CN(CCCOc1cccc2ccccc12)C(=O)c1csc(-c2ccccc2Cl)n1',
#  'COc1ccc(CCC(CN)Oc2cc(C)ccc2C)c(OC)c1',
#  'O=C(O)c1cncnc1C1CNC(c2ccccc2)C1',
#  'CCN=c1[nH]c(SC(C)CC#N)nc(=NC)[nH]1',
#  'SSCCCCCCSSCCCCCOCCCN1CC2CCC1C2',
#  'O=S1(=O)CCN(CC(O)=NC2CCN(c3ccccn3)C2)CC1',
#  'COCOC(O)=Nc1cccnc1C1C=CC(c2ccccn2)=CC1',
#  'CCCOc1ccc(C(O)N2C(=O)C(=O)C(c3cccc4ccccc34)C2c2cccc(Oc3ccccc3)c2)cc1',
#  'CCCCC1C(O)=NC2(CCCCC2)C(=O)N1CC(C)C',
#  'CCN=C(O)C(CC)N(Cc1cccc(C)c1)C(=O)CN(c1ccccc1I)S(C)(=O)=O',
#  'Cc1ccc(S(=O)(=O)N=c2ccc(N3CCCC3)n[nH]2)cc1C(O)=NC(C)c1ccccc1',
#  'C=CCCC(=O)N=c1sc2cc(-c3ccc(S(C)(=O)=O)cc3)ccc2n1CCOC',
#  'COCC1=NCCCC1(C)N1C(=O)c2ccccc2C1=O',
#  'COCc1noc(CN(C)CCC(=O)c2cccc(Cl)c2Cl)n1',
#  'N=C(O)C1(CCN=C(O)Nc2ccc(S(=O)(=O)c3ccc(F)cc3)c(C(F)(F)F)n2)CC1',
#  'CCCCC(CC)CC(C(=O)O)C1CCCC1',
#  'CC(C)(C)OC(=O)C(c1ccccc1)c1cc(O)cc(O)c1',
#  'Cc1cnc(N2CCC3CC(C2)N3Cc2cocc2)[nH]1',
#  'CC1CN(CCC(=O)c2ccccc2Br)CC1C(=O)O',
#  'Cc1c(C)c2c(s1)n(C(C)C)c1ccc(C(=O)O)cc1c2=O',
#  'CCC1(CC)CC(=O)N(CCc2ccc(Br)cc2)C1=O',
#  'COC(=O)c1nn(C)c(C2Oc3ccccc3C(=O)C2C(=O)c2ccco2)c1',
#  'C=CCCc1cc(-c2cccc(OC3Cc4ccccc4C3(CCC)c3cc(F)ccc3C)c2)nc(C(C)(C)C)n1',
#  'CC(C)C1CCC(CC(=O)C2(Cl)CCC(c3cc4cn(C)nc4cc3F)=N2)CC1',
#  'Cc1ccc(C(CN=C(O)c2ccc([N+](=O)[O-])cc2O)N2CCOCC2)cc1',
#  'CN(C)C1CCN(C(=O)c2cc(C3CC3)c3c([O-])nc(=O)n(CC4CC4)c3n2)C1',
#  'COc1cccc(CCCOc2ccc(C3CCC(O)(N(C)C(=O)OC(C)(C)C)CC3)cc2)c1',
#  'CCc1nnc(C2CC(c3ccccc3)CN2CC(O)=NCc2ccc(C)cc2)n1CO',
#  'COC1OCCCCC(C)Oc2ccc(N=C(C)O)cc2C(=O)N(C(C)C(O)=NC2(C(O)=NS(=O)(=O)C3CC3)CCCC2)CC1C',
#  'CC(C)CCOc1ccc(O)cc1Br',
#  'CC(=O)C1CN(C(=O)c2cccn2C)CC1CN1CCN(c2cc(O)ncn2)CC1',
#  'CN1CCCC(C)(C(=O)Nc2ccc(CCC(=O)O)cc2)C1',
#  'N#Cc1nc(NCC(=O)N2CCN(C(=O)CN=C(O)c3nccnc3C3C=CC(F)=C(F)C3)CC2)ccc1',
#  'CC(N)C(O)c1ccc(F)c2ccccc12',
#  'O=C(O)c1cc(Cl)c(C(F)F)c(Cl)n1',
#  'COCCN(CCN(C)C)Cc1nc(-c2cscc2)no1',
#  'CC(C)(C)c1nn2c(Oc3ccc(NC(=O)c4ccncc4I)cc3)nnc2cc1',
#  'Cc1nc2ccccc2c(=O)n1CC(=O)OCC(=O)N1CCCCC1C',
#  'OC1=NC(c2ccc(Cc3nn(Cc4ccccc4C(F)(F)F)cc3Br)o2)C(O)=N1',
#  'COc1ccc(C(C)C(N)c2ccc(I)cc2)c(OC)c1',
#  'CCCC1(OC(=O)c2ccc(C(C)(C)C)c(C(C)(C)C)c2O)CC1',
#  'CC(C)(C)c1ccc(N2C(=O)N=C(O)C(c3ccccc3COCc3ccc(Br)cc3)C2=O)cc1',
#  'CCN(CC)C(=O)c1cc(N=c2cc[nH]cc2)ccn1',
#  'CCCC(C)N(C)Cc1ccccc1C(=O)OC',
#  'N#CCN(CC#N)C(=O)OCCc1ccccc1',
#  'COC1(CNC(=N)Nc2ccc(OC(F)(F)F)cc2)CCOCC1',
#  'COC(=O)c1ccccc1SCc1cc(O)nc(N(C)C)n1',
#  'CCc1noc(CON=C(O)c2ccc(Cl)cc2OCc2cccnc2)n1',
#  'O=C(COc1ccc(Br)cc1)Oc1ccc2c(=O)c(-c3ccc(Cl)cc3)coc2c1',
#  'Cc1cc(C(=O)C2=NN(N(Cc3ccccc3)CC(F)F)C(=O)CC2)ccc1',
#  'CCC(C)N=c1nc(N2CCNCC2)[nH]c(=NCC(C)C)[nH]1',
#  'CCN(CC)CC(=O)N(C)Cc1nc(-c2cccs2)cs1',
#  'CCOC(=O)c1nn(C(C)C)c2c(CNC(C)(C)C)cccc12',
#  'Cc1cc(Nc2csc(C(=O)N3CCC4(CC3)OCCO4)n2)ccc1',
#  'CCC1C(N)C(C=NC)C2CCC1C(CC)(CC)C2',
#  'N=c1cc(N)nc(N2CCC(N=c3ncn(Cc4ccc(Cl)cc4)[nH]3)CC2)[nH]1',
#  'COc1ccc(Br)cc1C(O)=NC(C)(C)CO',
#  'COc1ccccc1NC(=O)c1ccc(NCC(=O)SC(C)C(O)=NC2CC2)cc1',
#  'Cc1ccc(S(=O)(=O)Nc2c[nH]c3ccc(N=C(O)C4CC4)cc23)cc1',
#  'CC1SC=CC1NCCCO',
#  'Nc1cc(F)c(F)cc1OCCCc1ccccc1',
#  'CCC(C(O)=Nc1cccc(C)c1C)N1C(=O)c2cccc([N+](=O)[O-])c2C1=O',
#  'CC(C)N(CC#N)Cc1cccc(-n2ccnc2)n1',
#  'O=C(c1ccc(Cl)cc1)N1CCCN(c2ncc(C3CCOCC3)cn2)CC1',
#  'COc1ccc2[nH+]cc(CCNCc3ccccc3)c(C(O)CCC3(CC(=O)O)CCSCC3)c2c1',
#  'COCCNC(=O)c1ccc(N2C(=O)c3cc(Cl)c(Cl)cc3C2=O)c(C)c1',
#  'O=C(Nc1nc2c(s1)C(c1ccccc1)CCC2)c1cccs1',
#  'COc1ccc(C(C)=O)c(CON=C(O)c2cccc(CN3CCS(=O)(=O)CC3)c2)c1',
#  'COc1ccc(OCC(F)(F)F)c(CN=C(O)CN2C(=O)C(C)(c3cccs3)N=C2O)c1',
#  'COc1ccc(C(NCCCC(O)=Nc2c(C)cc(C)cc2C)c2ccc(F)cc2)cc1',
#  'Cc1ccc(C)c(C2(C)N=C(O)N(NC=C3C=CC=CC3=O)C2=O)c1',
#  'CCc1ccccc1NC(=O)c1ccc(N)c(C)c1',
#  'CCC1(CC)CN(C(=O)C2(N)CC2)CCS1=O',
#  'CSC1(CN=C(O)N2CCCC2c2cc3c(C)[nH]nc3nc2)CCOCC1',
#  'COc1cccc(C2CCCN2CC(=O)N(C)CCCC(O)=NC2CC2)c1',
#  'Cc1ccc(S(C)(=O)=O)c(NCc2nc(C)ccc2O)c1',
#  'O=S(=O)(c1ccccc1)N1CC2CC(C1)N2Cc1ccc(-c2ccco2)s1',
#  'OCCC1Oc2ccccc2C2CC(c3ccc(-c4ccc(C(F)(F)F)cc4)cc3)NN12',
#  'CCN(CC(O)=NO)Cc1c(Cl)[nH+]c(C)c(=O)n1Cc1ccc(F)cc1F',
#  'CNCCC1CCCCN1C(=O)c1ccc(F)c(C)c1',
#  'CCOc1c(C(C)=CC(O)=Nc2ncccn2)cc2c(-c3ccc(F)cc3)coc2c1C',
#  'Cc1ccc(C2CNCC(C)O2)s1',
#  'COc1cc(-c2ccc(S(=O)(=O)N3CCNCC3)cc2)c(OC)c(OC)c1',
#  'CN(CCCC(=O)O)S(=O)(=O)c1cnc2c(c1)c(O)nc(=O)n2C',
#  'O=C(CCc1ccccc1)N1CCCC(Cc2nc(-c3ccc(Cl)cc3)no2)C1',
#  'Cc1ccccc1OCc1ccc(C(=O)N(C)Cc2cnccn2)o1',
#  'CC(C)C(N)C(=O)C1CC(c2n[nH]cn2)N(Nc2ncc3ncnc-3[nH]2)C1',
#  'COC(=O)c1ccc(NC(O)=NC2CCc3cc(F)ccc32)cc1',
#  'CC(C)c1nn(-c2cccc(F)c2)c(C(=O)NCc2nncn2-c2ccccc2)n1',
#  'Cc1ccc(C(CN)N(C)Cc2cnc[nH]2)cc1',
#  'CCCC1N=C(O)Cc2cccc(O)c2CN(CC(C)C)C1=O',
#  'C=C(C)C(=O)OCCOC(=O)C1C2C=CC(O2)C1C(=O)OCCC',
#  'C=CCOCCOc1ccc(OC(=O)c2ccc(OCC=C)c(OC)c2)cc1',
#  'O=C(NN=C1C=CC2CCCCC2C1=O)c1c(-c2ccccc2)oc(=O)cc1',
#  'CC1CN(Cc2ccc(CNC(O)=NCCS(=O)C(C)C)cc2)CC(C)O1',
#  'CN=c1nc(-c2ccc(Br)cc2)[nH]c(C)c1C(O)=NC(C)c1ncc(-c2ccccc2-c2ccccc2-c2n[nH]nn2)cn1',
#  'CCCC(=O)C1CC(O)=NC(=N)N1',
#  'Cc1c([N+](=O)[O-])cccc1C(C)N=C(O)c1cccc([N+](=O)[O-])c1',
#  'Cc1nc(CC2CCCN(C(=O)c3cc(S(=O)(=O)N(C)C)c[nH]3)C2)no1',
#  'Cc1cc(=NC(=O)C2CCCCN2C(=O)C(C)O)[nH]o1',
#  'CC1=Nc2c(cc(Oc3ccccc3O)c(C)c2C)Nc2ccc(Oc3ccccc3[N+](=O)[O-])cc12',
#  'C=COCCC(=O)C1CCN(C(c2ccc(OC=C)cc2)N(c2ccc(CC)c(Cl)c2)c2ccc3nc(O)[nH]c3c2)CC1',
#  'CCOC(=O)C1(C(=O)OC)CCCN1C(=O)OC(C)(C)C',
#  'Nc1cc(Br)ccc1C(O)=Nc1cc(C(F)F)ccc1',
#  'CCCCCCCCCC1OC2(CC)C(=C1C(=O)OC)SC1SC(c3ncncn3)C1C2O',
#  'CC(=O)N=C1SC2CS(=O)(=O)CC2N1c1ccc(OCc2ccccc2)cc1',
#  'CCN(CC(=O)Oc1ccc(C)cc1C)C(C(=O)O)c1ccccc1',
#  'CCCC(N)CC(=O)N(C)CC1CCCCC1',
#  'CCN(Cc1cccnc1)c1cnnc(C)c1',
#  'CCCc1nn(C2CCCCO2)c(CN=[N+]=[N-])n1',
#  'CC1(C)C(=O)C(c2ccc(O)cc2)C1Oc1ccccc1',
#  'NC(c1ccncc1)c1nnc(C2CCC2)o1',
#  'CCCc1ccc(C(C)=O)c(O)c1OCC#CCCCOc1cccc(-c2cccc(CC(=O)O)c2Cl)c1CN',
#  'COc1nc(C2CCN(N3CCCC3C)CC2)c(F)c(C(F)(F)F)n1',
#  'O=C(CCc1ccccc1F)N1CCN(c2nc(-c3ccc(F)cc3)cs2)CC1',
#  'O=C(c1nocc1)N1CCN(C(=O)C2CCCO2)CC1',
#  'C=CCC1(C(=O)OO)CC(O)C2(O)C(=O)C(C)=COC2(O)C1OC(=O)CCCCCCCCC',
#  'CC(C)C1CN(c2ccc(Br)cc2)C(C)(C)CN1CC(=O)CCc1ccccc1',
#  'Cc1ccc(NC(C)C(O)=Nc2ccccc2C)cc1',
#  'CSCC(C)C(O)=Nc1cc(C(=O)N2CCCC2)ccc1Cl',
#  'O=C(OCc1ccccc1)N1CC(Nc2c(Br)cncc2[N+](=O)[O-])C1',
#  'CCC(NC(=O)c1cc(C)c(NC(=O)C2CC2)s1)c1ccccc1OC',
#  'CCc1cc(Br)cc(CN)c1OCc1cccc(F)c1',
#  'CCc1ccc(NC(=O)C(CC)Oc2cccc(C=O)c2)cc1',
#  'CCc1ccc(NCc2cccc(OCc3ccccn3)c2)cc1',
#  'CCC(CN(Cc1ccco1)C(=O)C(O)C(O)C(O)=NC(C)(C)C)C(O)=NC1CCCCC1',
#  'CCOC(=O)C(C)N=C(O)c1cccc(N)c1-c1ccc(Cl)c(Cl)c1',
#  'CCOC(=O)C(N=C(O)c1cc(-c2cccs2)nc2c1nnn2C(C)C)c1ccccc1',
#  'CCCCOCC(=O)N(Cc1ccccc1)S(=O)(=O)c1ccc(Cl)cc1',
#  'CCC(=O)N=c1[nH]nc(N2CCN(C(=O)c3cscc3)CC2)s1',
#  'CC(Cc1cccnc1)N(CC(=O)O)c1ccccc1',
#  'COC(=O)c1ccc2NC(NS(=O)(=O)c3cccnc3)C(N)Cc2c1',
#  'CC(C)CC(C)NC(=O)C(=O)Nc1cccc(OCC(F)F)n1',
#  'CCOC(=O)c1nc2cc(Cl)ccc2c(N=C(O)C2CCCC2)c1C(C)(C)C',
#  'C[N+](C)(C)CC(COC(=O)c1ccc(Cl)cc1Cl)OC(=O)c1ccc(Cl)cc1',
#  'FC(F)(F)c1[c]ccc(-c2ncccn2)c1',
#  'CN=C(O)C(N)c1ccc(OC2CC2)c(OC)c1',
#  'COc1ccccc1-c1nn(CCN2CCCC2=O)nn1',
#  'CCN(C(=O)c1cc(Br)cc(O)c1O)C1CCS(=O)(=O)C1',
#  'CCOc1nc2c(N3CCN(C(=O)c4c(N=C(C)O)sc(C)c4C)CC3)cccc2s1',
#  'CN=C(O)C(NC(=O)c1ccc(-c2ccccc2F)s1)c1ccc(F)c(C)c1',
#  'COc1ccc(S(=O)(=O)NC2CCN(c3ccccc3)C2C)cc1',
#  'CS(=O)(=O)CCCCCN=C(O)Cc1csc(-c2ccc(Cl)cc2)n1',
#  'CCCNCC1(CC)CCC(C(F)(F)F)CN1',
#  'CN(CC(O)=NC1CC1)S(=O)(=O)c1cccc(C(=O)C=Cc2ccccc2)c1',
#  'Cc1c(N=C(O)C=Cc2ccco2)n(Cc2cccc(OC(F)F)c2)nc1',
#  'CCOC(=O)C1CCCN(Cc2c[nH]c(-c3ccccc3)c2)C1',
#  'COCCCC(O)=Nc1cccc(Br)c1-c1ccc(C)cc1',
#  'CC1C(CN2CCC(C)(O)C2)OC(c2ccc(N=C(O)c3ccc(O)cc3)cc2)OC1c1ccc(CO)cc1',
#  'CC(C(O)=NCCC(C)(C)C)C1CCN(c2c[nH]c3ncccc23)CC1',
#  'Nc1nnc(Cl)cc1C(O)=NCc1ncc[nH]1',
#  'COCC(C)NCc1c(C)n(CCO)nc1C',
#  'FC(F)C1(Nc2ccc(C(F)(F)F)cc2)CC1',
#  'CC(=O)c1csc(CNc2ccc(-n3nccn3)cc2)c1',
#  'CC(=O)C1=C(O)CC(c2ccccc2)[NH2+]C1c1ccccc1',
#  'CC(C)C(=O)N(CC1=Cc2cc(Br)ccc2OC1c1cccc(OCCCCN)c1)C(C)C',
#  'CCOc1ccc(Oc2ccc([N-]CC(=O)c3c(C)[nH]c4ccccc34)cc2)cc1',
#  'CCCNCCc1nccn1CCOCCCOC',
#  'COC1OC(COS(=O)(=O)O)C(OC(O)=Nc2ccccc2Cl)C1OC(C)=O',
#  'O=C(O)CN(CCc1cccc(Cl)c1)S(=O)(=O)c1ccc(Cl)c(Cl)c1',
#  'CCOc1ccc(C(O)=NNc2nc(SC)n[nH]2)cc1',
#  'C=CC(CC1(C(=O)O)Nc2ccccc2-c2c(S)cccc21)c1ccc2ccccc2c1',
#  'Cc1noc(C)c1S(=O)(=O)NCCN=C(O)CCOc1ccc(Cl)cc1',
#  'COCC(=O)N(CCCCCl)c1cc([N+](=O)[O-])ccc1Cl',
#  'COc1ccc(-c2csc(C(=O)OCCC3CCCN3C(=O)O)n2)c(OC)c1',
#  'CN(Cc1ccc(Cl)cc1)C(=O)Nc1ccc(C(=O)N2CCCCCC2)cc1',
#  'CCOc1cc(CBr)c(OC(F)F)c(I)c1',
#  'Cc1ccc(C2C(=O)N(c3ccc(Cl)cc3)C2CCC(O)c2ccc(F)cc2)cc1',
#  'Cn1cc(NC(O)=Nc2cccc(Cl)c2)cc1C(=O)N=c1[nH]nc(-c2ccc(Cl)cc2)s1',
#  'Cc1ccccc1CN(C)C(=O)C1CCc2ccccc2O1',
#  'COc1ccc(CC(O)=NC(C)c2ccc(Br)cc2)c([N+](=O)[O-])c1',
#  'Cc1ccc(C2CCN(NC(=O)C(=O)Nc3cccc(-c4nocn4)c3)C2=O)cc1',
#  'CN(C(O)=NCC(O)=NC(C)(C)C)C1CCCC(c2ccccc2)C1',
#  'Fc1cc(Nc2ccc(Cl)c(Br)c2)cnc1',
#  'OCC(CO)(CO)C12CC3CC(CC(C3)C1)C2',
#  'O=C(O)CCc1ccc(N2CCOCC2)c(NC(=O)c2ccc(-c3ccc(C(F)(F)F)cc3)s2)c1',
#  'N#Cc1ccc(C(=O)C2CCCCN2C(O)c2ccccc2)cc1',
#  'O=C([O-])Cn1cnc2ccccc2c1=O',
#  'Cc1ccc(N(CC(O)=NC(C)(C)C)C(=O)c2cccc3ccccc23)cc1',
#  'COC(=O)c1c(NC(=O)c2ccc3cc(OC)ncc3c2)sc(Br)c1',
#  'CCC(CC)CN=C(O)C(C)Nc1ccc(Br)cc1OC',
#  'Cc1ncc(CNc2cc(F)cc(F)c2)[nH]1',
#  'COCC(C)NCC(C)(C)OC',
#  'CN=C(O)c1cc(CSCC(O)=Nc2ccccc2SCC#N)ccc1',
#  'Cc1n[nH]c(=O)c2ccc(N=C(O)C(C)n3cncn3)cc12',
#  'CN1C(=C(C#N)c2c([O-])n(-c3ccc([N+](=O)[O-])cc3)nc2C(C)(C)C)C(C)(C)c2ccccc21',
#  'Cn1c2c(NCCC2)c(=O)n(C(CO)C(C)(C)C)c1=O',
#  'Cc1ncccc1N(C)C(=O)C1CC1c1cccs1',
#  'Cc1ccccc1C1(O)CC2CCC(C1)C2(C)C',
#  'Cc1ncc(COC(=O)C(C)c2ccccc2)s1',
#  'COc1ccc(Nc2nc(=NC3CC3)[nH]c(Nc3cccs3)n2)cc1',
#  'CCC(CC(O)C(Br)C=C1CCC1)NCCc1ccccc1',
#  'COc1ccc(-c2nc3cc(Cl)c(C)cc3n2-c2cc(C(C)(C)C)c(O)c([N+](=O)[O-])c2)cc1',
#  'N#CC1C(O)=NC(O)=NC1c1c(F)cc(N)cc1F',
#  'CC1OC(C2OC=C(C(=O)OC3OC(CO)C(O)C(O)C3O)C3(O)CC(O)C(C)(C)C23)C(O)C(O)C1O',
#  'CCc1cn(-c2cc(=NC(C)C(C)(C)C)[nH]c(NC)n2)nc1',
#  'CC(C)(CCCCCC#N)C1(O)CC(=O)C(C)(C)C(O)(C(F)(F)F)C1(C#N)C#N',
#  'C=CCN=C(O)C(C#N)c1cc(COC)c(OC)c(OC)c1',
#  'CCc1ccc(Cc2ccc(CC3(c4ccccc4)C=CC(c4ccc(N(C)C)cc4)C=C3)cc2)nc1',
#  'CCOC(=O)OC(=O)C(O)=Nc1ccc(NCC(C)(CC)c2cccc(Cl)c2)cc1',
#  'COc1ccc2C3=C(C)C=C(C)N(O)C3CC(=O)c2c1',
#  'COCCCN1C(=O)CSc2ccc(C(O)=NCCC(=O)N(C)Cc3ccncc3)cc21',
#  'CCC=CCC=CCCC(=O)CCCCCCCCOCCCCCCCCCCCCCCCCCCCCC=CCCCCCCCCCCCCCCCCCCCC(O)=NC(CO)C(O)C=CCCCCCCCCCCCCC',
#  'C=CC(O)=Nc1c(N=C(O)C=C)c(F)c2[nH]cc(C#N)c(=Nc3ccc(OCCCC(O)CC(C)C)c(Cl)c3)c2c1',
#  'CCOC(=O)C1CCN(CC(=O)Oc2ccc3C(=O)C(c4ccc(COC)c(OC)c4)Oc3c2)CC1',
#  'CCNC(c1ccc(F)cn1)c1cc(C)ccc1Cl',
#  'COCC(O)=NC(CNc1ccc([N+](=O)[O-])cc1)C1CC1',
#  'Cc1ccc(F)cc1S(=O)(=O)Nc1ccccc1-c1nc2ccccc2[nH]c1=O',
#  'CCN1CCN(CC(C)CN=C(O)CCN=C(O)C(C)(C)C)CC1',
#  'O=C1N(C2CCOC2)CCC12CCCN(c1cscc1)C2',
#  'Cc1cc(C2N=C(S)N(Cc3ccc4OCOc4c3)C2c2ccccn2)c(C)n1-c1ccc(N=C(O)c2ccccc2)c(Cl)c1',
#  'O=S(=O)(CCc1ccccc1)NCC1(c2cccc(Br)c2)CC1',
#  'CCOC(=O)C(c1ccc(OC)cc1)C(C)C(=O)O',
#  'CN1CCC(c2cn(Cc3nc(=N)[nH]cc3)c(-c3ccc(F)cc3)n2)CC1',
#  'CSc1ccc(NC(C)c2ccc(F)cc2O)nc1',
#  'CC(=O)CCc1csc2c1c(=O)n(-c1ccccc1)cn2',
#  'CCN(CC)CCCC(C)NC(=O)c1n[nH]cc1N',
#  'CC(C)Oc1ccc(F)c(C(=O)N(C)CC(=O)NC(C)c2ccccc2)c1',
#  'CCCCOC(=O)C1CSC(c2cccc(OCCC)c2)N1',
#  'COc1cccc(C2CCCN2CC(=O)SCCOc2ccccc2F)c1',
#  'COC1CCCN(C(=O)c2ncccc2C)C1',
#  'CCC(C)C(N=C1NS(=O)(=O)c2ccccc12)C(O)=Nc1c(C(=O)N(Cc2ccccc2)C(C)C)c(-c2ccc(Cl)cc2)c(C)s1',
#  'CCS(=O)(=O)C1CN(C(=O)c2ccc3c(c2)c(=O)n(C)c(=O)n3C)C1',
#  'CC(C)=CS(=O)(=O)C1CCCC(C)C1C',
#  'Cc1ccc(S(=O)(=O)NC(=O)CN=C(O)C2CCCCC2Nc2ccc(C(N)=O)cc2)cc1',
#  'CC1CN(C(=O)c2c[nH]c3ccccc23)CC(C)O1',
#  'CCOC(=O)C1CCN(CC(=O)N(Cc2ccc(F)cc2)S(=O)(=O)c2cccc([N+](=O)[O-])c2)CC1',
#  'Cc1cc(=O)n2nc(C3CCN(Cc4cccc(F)c4)CC3)sc2n1',
#  'CCCc1cc(Br)c(C(=O)C=Cc2cc(Br)cs2)s1',
#  'CCOC(=O)c1c(C)n(Cc2csc(C(=O)N(C)C)n2)nn1',
#  'COc1ccccc1N(C)CC(=O)OC(C)c1cccnc1',
#  '[N-]=[N+]=NS(=O)(=O)c1c(OCc2ccc(Cl)cc2)oc(=O)c(O)c1CN1CCOCC1',
#  'CN1CC2CCC1CN(C(=O)c1cc(Br)cs1)C2',
#  'Oc1ccccc1-c1noc(-c2cccc3ccccc23)c1Sc1ccccc1',
#  'Nc1ccc(-c2nc3cc(Br)c(F)cc3[nH]2)[nH]1',
#  'COC(=O)C1(c2ccccc2)CC1c1ccccc1',
#  'COc1cc(C(CN)N2CCC(O)CC2)c(OC)c(OC)c1',
#  'Cc1c(NC(=O)c2cc(-c3cccc(Cl)c3)c(O)nn2)cnn1C',
#  'O=C(c1ccc(S(=O)(=O)N2CCCC2)cc1)N1CCCSC1=NC1CCCCC1',
#  'CN1CCN(CCC(=O)c2ccc(NCC(=O)c3csc(COc4ccc(Cl)cc4)n3)cc2)CC1',
#  'CCCCOCCNCc1cc(O)cc(F)c1',
#  'CCOC(=O)CCC(=O)N1CCC2(CC1)CN(CCC(=O)N1CCN(C(=O)c3c(F)cccc3Cl)C(C(C)(C)C)C1)c1ccccc12',
#  'COC1CCN(C(O)=NC(C)c2ccc(-n3ccnn3)cc2)C1',
#  'O=c1oc2ccccc2cc1C(O)=NCC1(c2ccccc2Cl)CCOCC1',
#  'CN(C)C1CC(N=[N+]=[N-])(C(=O)O)C(O[Si](C)(C)C(C)(C)C)O1',
#  'CCc1cccc(CC[NH+]=C(O)NN2Cc3ccccc3C2)c1',
#  'N#CC(CC(=N)C(=O)c1ccncc1)c1ccccc1',
#  'CC(C)CN1C(=O)CN(c2ccc(Cl)cc2)C(C)C1=O',
#  'COC(=O)CC(CN=C(O)N=c1cc(C)o[nH]1)c1ccccc1',
#  'CN(CC(=O)N1CCN(C(=O)c2cc(Br)ccc2F)CC1)Cc1ccco1',
#  'COC(=O)C(N)c1ccc(N(C)C)c(Cl)c1',
#  'Cc1cc(F)ccc1C1(NC(=O)c2nc3ccccc3o2)CCOCC1',
#  'CNC1CCN(C2CCC(OC)C2C)C1=O',
#  'CC(C)N=C(O)c1cc(CN=C(O)N(C)CC(O)=NC(C)(C)C)ccc1',
#  'CC(C)(Oc1ccc(-c2c3c(c(Cl)cc2)cc(C(=O)N2CC(c4ccccn4)CC2C#N)n3CCc2ccccc2)cc1)C(=O)O',
#  'O=C(O)C1CCC(c2ccc(Br)cc2Cl)O1',
#  'COc1ccccc1Oc1nc2ccccc2cc1C(=N)S',
#  'CC1C(C(=O)O)CCN1S(=O)(=O)c1ccc2CCCc2c1',
#  'CC(C)(C)n1cnn(CC(=O)N(C2C=CS(=O)(=O)C2)C2CC2)c1=O',
#  'CN(Cc1ccccc1)C(=O)CCC(=O)c1ccc(Cl)cc1',
#  'Nc1c(Nc2ccc(I)cc2Cl)c(C(O)=Nc2cc(F)c(Br)c(F)c2)ccc1',
#  'CNCc1cnc2ccccn12',
#  'CC1C(=O)N(C)CCN1CC(=O)Oc1ccc(OCc2ccccc2)cc1',
#  'CCN1C(Cl)=CC(Cl)=C(Cl)C1Cl',
#  'CCOCCCCCCOC(=O)CCC(=O)N(CCC#N)c1ccccc1',
#  'COc1ccc(OC)c2c1[nH]cc2C1OCCCC1=O',
#  'CCCN(CC1CC1)C(=O)C(CC)(CC)CN',
#  'COc1ccc(CN(C)C(=O)C(C)Oc2cccc([N+](=O)[O-])c2)cc1',
#  'COc1cc(C(=O)O)c(OCC(=O)c2ccc3OCOc3c2)c(Cl)c1',
#  'COc1ccc(CN=C(O)N(C)CC(C)c2cscc2)cc1',
#  'CN(C)C(=O)c1ccc(-c2ccc(F)c(C(F)(F)F)c2)cc1',
#  'C=C1CC(C)(O)CC2CC(O)C3C(CC(O)C4(C)C(C(C)CCCC(C)C)CCC34)C12',
#  'O=C1C2CCCN2c2cn(CC(O)=NCC(Cl)(Cl)Cl)nc2N1c1ccccc1',
#  'CNC1(CN2CCC(=O)CC2)CCN2CCC1C2',
#  'O=C(Nc1nn(C2CCS(=O)(=O)C2)c(C2CC2)c1)c1ccc2OCOc2c1',
#  'Cc1cc(Br)ccc1CC(=O)N(CC#N)c1ccc(F)cc1',
#  'CN=c1[nH]c(N2CCCN(C)CC2)nc(C2CC2)c1Br',
#  'CC(C)N(CC(O)=Nc1ccccc1N=C(O)C1CC1)Cc1csc([N+](=O)[O-])c1',
#  'Cc1nnc(CS(=O)(=O)c2ccc(Cl)nc2)n1C',
#  'CCCCCCCCCCN=C(O)C(c1ccc2OCOc2c1)N(Cc1ccc(C)o1)Cc1ccc(C)o1',
#  'CCC1(C(=O)C2CCN(n3cccc3)CC2)CCCN1',
#  'N=C(O)CCNc1cc2c(cc1[N+](=O)[O-])CCC(O)=N2',
#  'O=CC1C(=O)N(Cc2ccc([N+](=O)[O-])cc2)C(=O)c2ccc([N+](=O)[O-])cc21',
#  'COc1ccccc1C1Oc2cc(O)ccc2C(C)=C1c1ccccc1',
#  'CC(C)CCNCC1=CCCOC1',
#  'N=C(O)C1COCCN1CC(=O)O',
#  'CCCCC1C(O)=NC(=O)N(N(CC(C)C)C(=O)Cc2ccc(OC)cc2)C1N',
#  'CCC(CC)CC(O)=NCCCOCC1CC1',
#  'COc1ccc(OC(F)F)c(CN(C)CCOc2cc(C)cc(C)c2)c1',
#  'CN(CC(O)=Nc1cc(-n2cccn2)ccc1F)S(=O)(=O)c1ccc(Br)cc1',
#  'CC(C)CC[NH+]=C(O)C(C)N1CCCC2(CC=CCC2)C1',
#  'COCCc1ccc(S(C)=O)cc1',
#  'O=C1COCCN1Cc1ccc(C2CC2C(O)=Nc2cccc(F)c2F)cc1',
#  'C=CCOC(=O)OC1=CC(c2ccccc2)NC(c2ccccc2)=C1OCc1ccccc1',
#  'Cc1nn(C(=O)N2CCC(O)(Cc3cccnc3)CC2)c(C)c1CN1CCC(c2ccc(F)cc2)CC1',
#  'CCN(Cc1ncc[nH]1)C1CCS(=O)(=O)C1',
#  'COCCOC1=CC(=C2C=C(CN=C(O)CN=[N+]=[N-])N=N2)ON1',
#  'CN1CCN(CC(=O)Sc2ccc(F)c(F)c2)CC1(C)C',
#  'CN=C(O)c1ccc(Cl)c(NCc2cccc(Cl)c2[N+](=O)[O-])c1',
#  'COC(=O)C1=CC2=NC(C)CC(c3ccc(Cl)cc3)N2N1',
#  'Cc1ccc(C)c(C(C)N=C(O)C2C3C4CCC(C4)C23)c1',
#  'OC(=Nc1ccccc1)Oc1cccc(OCCN2CCCC2)c1',
#  'CSC1(CNCc2ccc(C(=O)O)o2)CCCCC1',
#  'Cn1c(=O)cc(-c2ccncn2)n(CC(=O)N2CCc3ccccc3C2)c1=O',
#  'CC(C)CN(CC(=O)C1CCN(CO)C1)C1CC1',
#  'COBc1ccc(-c2ccc(OCCCC(=O)c3ccc(F)cc3C)cc2)cc1',
#  'CC(C(O)=NCc1ccco1)N(C)C1CCCCC1S(C)(=O)=O',
#  'C=CCCCC(NCc1ccccc1)OCCC=C',
#  'COc1c(C)nc2c(C3CCCNC3)cccn12',
#  'CCN=C(O)C(C)N(Cc1ccc(F)cc1)C(=O)CN(c1ccc2OCOc2c1)S(=O)(=O)CC',
#  'CCNCC(OC(C)(C)C)c1c(C)cc[nH]c1=N',
#  'CC(C)C1(C(O)=Nc2cn(C)nc2)CCC1',
#  'CC1CCN(Cc2coc(-c3ccccc3)n2)CC1CN',
#  'COC(=O)c1cccc2c1OC(N)(C1CC1)C2',
#  'N#Cc1cc(CN=C(O)c2ccc(-n3cccc3)c(F)c2)ccc1',
#  'N=c1[nH]ccc(-c2nc3cc(F)c(C(F)(F)F)cc3[nH]2)c1Cl',
#  'CN(CC(O)COc1ccc(F)cc1)C(=O)CN(c1ccc2OCCOc2c1)S(C)(=O)=O',
#  'CC(=NN=C1N=C(O)C(CC(=O)O)S1)c1cccs1',
#  'CCOc1ccc(-c2c(Cl)cc(C3=C(O)C(=O)N(OCC(C)C)C3c3ccc(Cl)cc3)cc2Cl)cc1',
#  'Cc1ccc(C(=O)c2c(C(Cl)=C(Cl)Cl)c(C(=O)C(F)(F)F)c(C)[nH]2)cc1',
#  'CN(CCCS)C(=O)C(F)(F)Cl',
#  'CCOC1(c2nnnn2-c2c(N)ccs2)CCC(C)CC1',
#  'CCN(C1CCN(C(O)=NC2CCCN(C(=O)C3CCCC3)C2)CC1)S(C)(=O)=O',
#  'CCC(C)N=C(O)C1CCCN1C(=O)c1ccccc1',
#  'COCCn1c(=O)c2c(nc3n(Cc4cccc(OC)c4)c(C)c(C)n23)n(C)c1=O',
#  'CC1=C(Cc2ccc(C)cc2)CS(F)(C(F)(F)F)N1c1ccccc1',
#  'N=C(C=CN)c1c(O)cc(O)c(C(=O)OC2CCC(C(O)=Nc3ccc4c(c3)cc(CN)n4CCC(F)(F)F)(c3ccccc3)C2)c1',
#  'Cc1ccc(C2COCCN2Cc2cccc(C(F)(F)F)c2)o1',
#  'COc1ccc(-c2nc3cc(cccn2C)CCCC3=NO)cc1',
#  'Cc1c(C2=CCC(=N)C=C2)cnc2c(-c3cc(F)cc(F)c3)c(-c3ccc(F)cc3OCCCC3CN(C(=O)OC(C)(C)C)CC4CCN34)nn12',
#  'CCN(CC)CC[CH+]C(C)(C)N(C)C',
#  'c1ccc2c(C3CCN(Cc4c(C5CC5)n5ccsc5n4)CC3)c[nH]c2c1',
#  'COC(=O)C(NC(=O)c1ccc(S(=O)(=O)NCC2CCCO2)cc1)c1cccnc1',
#  'CC(C)Oc1ccccc1N(CC(=O)N(Cc1ccccc1F)C(C)C(O)=NC(C)C(O)=NC(C)(C)C)S(C)(=O)=O',
#  'CS(=O)CCNc1ncc(Br)cn1',
#  'O=C(CC1CCN(S(=O)(=O)c2cc(Cl)cc(Cl)c2)CC1)N1CCN(c2ccccn2)CC1',
#  'COC(=O)c1cc(C(N=[N+]=[N-])c2cc(F)ccc2O)c(C(C)C)o1',
#  'O=C(c1nn2CCCc2c1)N1CCCN(C(=O)C2CCCC2)CC1',
#  'O=C(CN1CCOC1=O)C1CCCCN1Cc1cn(-c2ccccc2)nn1',
#  'CCNC(c1ccc(Br)c(Cl)c1)c1c(Cl)[nH]c2ccccc12',
#  'CCN(CC(=O)Sc1n[nH]c(N=c2cc(C)o[nH]2)n1)C1CCS(=O)(=O)C1',
#  'CCC(C)CCC(C(C)=CO)C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C',
#  'CCN(CC(O)=[NH+]c1cccc(CSCC(=[NH2+])O)c1)Cc1c(Cl)cccc1Cl',
#  '*C(=O)CN1CCCCC1C(O)=NC1CCCN=C1O',
#  'CNc1cc(N=c2[nH]c(Cl)nc(=Nc3nc4cc(OC)c(OC(C)C)cc4s3)[nH]2)ccc1OC1CCCC1',
#  'CC(C)(CNCc1cocc1)C1CCCC1',
#  'CN(Cc1ccccc1Cl)C(=O)c1ccc(Cl)cc1[N+](=O)[O-]',
#  'COC(=O)C1=C(S(=O)(=O)N2N=CCC2OC(C)(C)C)Cc2c(Cl)ccc(Cl)c2N1',
#  'CCc1cccc(CC(O)=NCC2Cc3ccccc32)c1',
#  'CC(C)(C)OCCc1cn(CNCCc2noc(C3CC3)n2)nc1-c1ccccc1',
#  'Nn1c(SCC(=O)N2CCc3cc([N+](=O)[O-])ccc32)nnc1-c1ccccn1',
#  'COc1ccc(C(=O)CCC(O)=Nc2cccc(N3CCOC3=O)c2)c(F)c1',
#  'O=C(C1=NCCC1)c1cc(F)c(F)c(O)c1F',
#  'CNCCC1OCCc2c(C(=O)OC)cccc21',
#  'C=CCc1nnc(-c2cccnc2)n1SCc1cccnc1C',
#  'O=C(NCCc1cc(=O)c2cc3c(cc2o1)C(=O)C(c1cccs1)C=C3)c1n[nH]c(Cc2ccccc2)n1',
#  'CCC(C(=O)N1CCc2ccccc21)N(c1ccccc1)S(C)(=O)=O',
#  'CCOc1ccc(C2=C(c3ccccc3)N=NC2C(O)=NN=Cc2ccc(Cl)cc2)cc1',
#  'CCOc1cccc(C2C3=CCC4C(=O)N(c5ccc(I)cc5)C(=O)C4C3CC3C(=O)N(O)C(=O)C32)c1O',
#  'CN=C1SC(CC(O)=Nc2ccc(Cl)c(C(F)(F)F)c2)C(=O)N1N=Cc1ccc(SC)cc1',
#  'COCC(NC(=O)c1cc2c(C)cc(F)cc2[nH]1)C1CC1',
#  'CC(C)(C)NCC1CCN(CCCCO)CC1',
#  'CS(=O)c1ccc(CNC(=O)c2c(-c3ccc(F)cc3)occ2)cc1',
#  'CCC1CCCCN1C(O)=NC1COCC1C(C)(C)C',
#  'CC1CC(C)C(N2CCC(C)(C)C2)C(N)C1',
#  'O=C(CCC(O)=NCCN=C(O)C1CC1)c1ccc(F)cc1F',
#  'CCC(C)c1ccc2[nH][nH]c(=N)c2c1',
#  'CC1(C)C(O)=Nc2ccc(S(=O)(=O)N3CC=C(c4cccs4)CC3)cc21',
#  'OC(=NC1CCCCC1)C1CN=C(O)N1Cc1ccccc1',
#  'Oc1c(Br)c(NCC(c2ccccc2)N2CCCC2)ncn1',
#  'CC1CC(=O)OC(C(=O)OCc2ccccc2)CCN1C(=O)OC(C)(C)C',
#  'CCOc1ccc(S(=O)(=O)N(CC(O)=Nc2cccc(C(C)=O)c2)c2ccc(F)cc2)cc1',
#  'CC(C)Oc1cccnc1CN=C(O)NCC(c1ccccc1)N1CCOCC1',
#  'C=CC=CCC(N=C(O)C1OC1C)C(C)C',
#  'Cn1nc(O)c2c(N3CCC(NC(=O)c4ccco4)CC3)c(C(=O)O)cnc21',
#  'Cc1ccc2nc(-c3c(C#N)c4ccccc4n3C3CCCCO3)sc2c1',
#  'CCOCC(=O)N1C(=O)C(c2c([O-])cc(C)n(C(C)CC)c2=O)=C(C)C1=Nc1c(C)n(C)nc1C',
#  'CC(C(=O)C(=O)c1ccc(Oc2ccc(OCCN(C)C(=O)C(F)(F)F)cc2)cc1)=C(N)C1C=c2ccccc2=C1',
#  'CNC1C2CCCC3(C)C2CC2CC1C23',
#  'COc1ccccc1CN=C(O)CSc1n[nH]cn1',
#  'CNCc1ccc(CC(F)(F)F)c(Br)c1',
#  'CCN(CC)CC[N+]1=C(C)C(SC)N(Cc2ccc(C)nc2)C1C',
#  'Cc1cc(N2CCCC2=O)ccc1NC(=O)c1cnc2c(c1)c(O)nc(=O)n2-c1ccccc1',
#  'Cc1c2nc(N(Cc3ccccn3)C(=O)c3ccc(S(=O)(=O)N(C)Cc4ccccc4)cc3)sc2ccc1Cl',
#  'CN1C(=O)CCC1C(=O)N1CCCN(CC(=O)N2CCCC2)CC1',
#  'Cc1cc(N2CCN(CCCCNC(=O)c3ccc4COCc4c3)CC2)ccc1',
#  'CC(OOCc1ccccc1)c1cc(CO[Si](C)(C)C(C)(C)C)nc(CN=C(O)COc2cccc3c2CN(C(=O)OC(C)(C)C)C3)c1',
#  'CC(OC(=O)C1CSC(=CC#N)N1)c1ccc(Cl)cc1',
#  'COC1(Cl)CC2(CCC(=O)O)CN1C(C)=N2',
#  'O=C(CN=C(O)c1cccc2ncccc12)N1CCN(C(=O)c2ccco2)CC1',
#  'COc1cccc(Cc2ccc(C(=O)c3cc(CCCF)c4C(=O)C(=O)C=C(c5ccc(F)cc5)c4c3)cc2)c1',
#  'CC(Sc1nncn1C)C(=O)OC(=O)CN(C(C)C)C(C)C',
#  'O=C(CSc1nc2ccccc2c(=O)n1CCc1ccccc1)N1CCCCC1CCO',
#  'CNC(=O)c1ccc(CCC(O)=NCc2nccs2)cc1',
#  'CS(=O)c1ccc(C(=O)NCc2ccc(Cl)cc2OC(F)F)cc1',
#  'CC(C)C(C)C(=O)N1CCCN(Cc2ccc(C#N)cc2)CC1',
#  'CCN(CC)S(=O)(=O)c1ccc(C(C)N=C(O)N(C)CC2CC2)cc1',
#  'C=CCN(CCOC)S(=O)(=O)CC(=O)OC',
#  'CCC(N)c1c(Cl)scc1',
#  'CC1=C(C)C2C(=O)N=C(Cn3cc(C(O)=NC(C)CO)nn3)N=C2S1',
#  'CCC(=O)c1cn(Cc2nc3ccc(F)cc3[nH]2)cc1',
#  'O=C1CN(CCc2ccccc2)CCN1c1ccccc1',
#  'O=C(COCC(=O)N1C(=O)c2ccccc2S1(=O)=O)Nc1ccc(OCC2CCCO2)cc1',
#  'CNCC(C)C(c1ccc(C)c(C)c1)C1CCC(C)O1',
#  'CCCCc1cnc(S(=O)(=O)CC(C)C)n1CN(Cc1ccc(OC)cc1)C(=O)Cc1ccccc1',
#  'Cc1cc(-c2nc3c(F)c(F)c(F)c(F)c3o2)ccc1N',
#  'CC(N=c1[nH]ncc2ccccc12)c1ccccc1',
#  'OC(=NC1CCC2(CCCCC2)CC1)C1CCC(CNCc2cc(C(F)(F)F)cc(C(F)(F)F)c2)O1',
#  'NC(C(O)=NC1CC(Oc2cc3ccccc3nc2-c2ccccc2F)C1)c1ccccc1',
#  'CCN=C(S)NN=C(O)C1=NC(C(C)(C)C)N=C1',
#  'Cc1c2Cc3ccc(-c4cccnc4)cc3C(=O)n3cc(C(O)=NO)nc3-c2c[nH]1',
#  'CS(=O)(=O)Nc1ccc(Cl)nc1-c1cc2ccccc2s1',
#  'CC(N=C(O)CSCCCO)c1ccc(F)cc1',
#  'Cc1cc(CN2CCC3(CCCN(CC(=O)OC4CCCC4)C3)C2)cnc1',
#  'COc1ccccc1N=C(S)N1CCC(c2ccc(O)cc2)CC1',
#  'Cc1c(N2CC(C(O)=NC3CCCCC3)CC2=O)cnn1-c1ccc(F)cc1',
#  'Cc1c(C(O)=Nc2ccc3cc[nH]c3c2)cnn1-c1ccccc1F',
#  'O=C(CN1CCN(c2ccccc2O)CC1)OCCN1CCCC1=O',
#  'O=C(c1noc(-c2ccc(F)c(C(F)(F)F)c2)c1)N1CCC(F)(F)C1',
#  'CS(=O)(=O)CC(O)=Nc1nc(-c2ccccc2)cs1',
#  'C=CCCC1(COP(C)(=O)Oc2ccc(Br)cc2)CC=C(CN2CC(C=C)=CC2=[OH+])C(OC(C)=O)C1',
#  'COC(=O)c1cccc(N2C(=O)C(c3ccc(COCC(=O)[O-])cc3OC)N=C2S)c1',
#  'CCC1SC(=NNC=C2C=CC(=O)C(OC)=C2)N=C1O',
#  'CC(N)c1ccc(N2CCCC(C)(C)CC2)cc1Br',
#  'CC1(C)OCC(=O)N(C2CCCCN=C2O)C1=O',
#  'CC(Cl)C(O)=NC(C)c1c[nH]nc1',
#  'CCCCCC1CCN(NCc2ccccc2C)C1',
#  'Cc1ccc(C(O)=NCC(O)=NC2CCCc3ccccc32)c(OC(F)F)c1',
#  'Cn1ccc(CN=C(O)N=c2cc(C(C)(C)C)o[nH]2)n1',
#  'C=C1C2COC3C(OC(C)=O)CCCC1(C)C1C(OCC4C(OC(C)=O)C5OC6(C)CCC7C(O)CC(CC)OC7OC6CC5C41)OC23',
#  'Cc1ccccc1-c1ccc(CCC(=O)O)n1C',
#  'COc1ccc(N(CC(=O)O)S(=O)(=O)c2ccc(C)c([N+](=O)[O-])c2)cc1',
#  'CCN(CC)CCC[O+]=C1C=CC(=C(N)C(=O)c2ccc(F)cc2F)S1',
#  'CCCCCC=CCCOC(O)=NCC(C)CCCCC(C)(C)C',
#  'C=CCN=C(O)CN1CCN(C(=O)S)CC1',
#  'CCc1ccc(OC)c(C(C=O)=CN(C)C)c1O',
#  'C=CCOC(=O)c1c(OC)ccc2c1c(OC(=O)c1ccccc1)c(Cn1c(C)ccc1C)n2-c1ccc(OC)cc1',
#  'Cc1cc(N2CCOCC2)ccc1C[NH+]1CCC(C(=O)N2CC(C)OC(C)C2)CC1',
#  'Clc1nn2c(N=Nc3cccc4ccccc34)c(-c3ccccc3)nc2cc1',
#  'CCOc1c(OCc2cccc3ccccc23)c(OCC)cc(C=NNC(=N)S)c1',
#  'CN=C(O)N1CCN(CC(=O)N2CCC3CCCCC3C2)CC1',
#  'Cc1ncc(NC(=O)c2ccc(CN(C)c3ncnc4c3nc[nH]4)cc2)nc1',
#  'C=S(=O)(C1CCN(C(=O)OC(C)(C)C)CC1)N1CCN(CCC(O)=Nc2nc3ccccc3s2)C(=N)C1C',
#  'Cc1ccc(C2CC(=O)c3c(C2)n(C(=O)C(O)=Nc2ccc(Cl)cc2)c(C)c3)cc1',
#  'COCCC(C)(O)CNCC(C)C(C)(C)C',
#  'CCCC(=O)N=c1[nH][nH]cc1-c1noc(-c2c(C)n(C)nc2C)c1',
#  'Cc1c2[nH]c(CC(C)(C)S(=O)(=O)c3ccccc3)nc2ccc1',
#  'CCC(N)COC(=O)c1cc(Cl)ccc1O',
#  'CCc1cc2nc(C)c(C3CCCN3CCc3ccncc3)c(=O)n2[nH]1',
#  'C=CCOc1ccc(CCCC(O)=NNC(=O)c2ccc(F)cc2)cc1',
#  'OC(=Nc1cc(F)ccc1F)N1CCCC1c1cccc(F)c1',
#  'CC(C)(C)COC1CCCN(c2nc3ccc(N=C(O)c4c(F)cccc4Cl)cc3o2)C1',
#  'CC1CCN(CCOc2ccc(N)c(N3CCN(c4ccc(C(=CN)c5nc6cc(F)c(F)cc6s5)cn4)C(C(C)C)C3)c2)CC1',
#  'COc1cc(C(O)=NC2CC(C)CCC2n2cnnn2)ccc1F',
#  'Cc1ccc(NC(=O)c2ccc(N=C(O)c3ccc(Cl)cc3)cc2)cc1N',
#  'O=C1C(C2CC2)N=C(O)N1CC(=O)N(c1ccccc1)C1CCCCC1',
#  'CCOc1cccc(C(N)c2cc(Br)cc(Br)c2)c1',
#  'CCC(C)(C)Oc1ccc(CCC(OC(=O)C2CCCCC2)c2ccccc2)cc1',
#  'CC1(C)C(O)=NCCN1C(=O)c1nn(-c2ccccc2Cl)cc1',
#  'CCCc1cncn1CNC',
#  'CCC1C(O)=NC(C)C(=O)N1CC1COc2ccccc2O1',
#  'CCC=CCC=CCC=CCC=CCC=CCCCCCCCC(=O)OCC(COCCCCCCCCC(=O)CCC=CCC=CCC)OC(=O)CCCCCCCCCCCCC',
#  'O=C(O)C=CC([O-])=Nc1cccc([N+](=O)[O-])c1',
#  'CCCN(CC1(CNC2CC2)CCOC1)C1CC1',
#  'CCc1cc(CC(C(=O)c2ccc(F)cc2)=C(C)Nc2ccc(C(C)C)cc2)c2ccccc2n1',
#  'COc1ccc(C2C(=C(O)c3cccs3)C(=O)C(=O)N2CCc2ccccc2)cc1',
#  'Cc1[nH+]c(CSCCC(O)=NC2CCN3CCCCC23)cs1',
#  'Cc1c(Cl)cccc1-n1c(-c2ccc(F)cc2)nn(CC(O)=NN=CC=Cc2ccccc2)c1=O',
#  'COCCC1=CC(=C(N)N=O)NN1',
#  'CCN(CC)C(=O)CS(=O)(=O)CC(c1ccco1)N1CCCCC1',
#  'CCOc1ccccc1C1CC(=O)N(c2nc3ccccc3n2CCCSc2ccc(C)cc2)C1',
#  'CNC1(C(C)=O)CCN(C)C1',
#  'Cc1c(C(=O)N2CCN(c3cccc(F)c3)CC2)cc(-c2ccc(Cl)cc2)n1-c1ccc(F)c(Cl)c1',
#  'CCCCOCCOC(C)(C)CCBr',
#  'C=CCc1nnc(C2CCCCN2Cc2ccccc2)n1CSC1=NC(C)CS1',
#  'CCNC(C)c1ccccc1C1CCCCN1CC',
#  'CN=C(O)COCC(=O)SC(=O)c1nnc(SCc2nnc(OC)o2)s1',
#  'CCC(C)(C)CCCC1(C(=O)OC)CCC2C3CCC4=CC(=O)C=CC4(C)C3C(O)CC21C',
#  'CC(Nc1ccc(N=C(O)C(C)N2C(=O)CCC2=O)cc1Cl)c1ccc(F)cc1',
#  'CN1CCC(c2ccc3OCOc3c2)C1',
#  'C=C(C)c1nc2c([nH]1)C(c1ccc(Br)cc1)N(C(=O)OCc1ccccc1)CC2',
#  'CN(C)c1ccc(CN=C(O)C2CSc3ccccc32)cc1',
#  'CCN1CCN(C2CN(C(=O)c3ccc(OC(C)(C)C)nn3)C2)CC1',
#  'CCCc1ccccc1NC(O)=NCC',
#  'COCCN(C(=O)C1CCCC(C(=O)N(C)C)C1)c1ccc(C#N)cc1',
#  'CC(C)c1ccc(-c2ccc(N=C(O)CC(NC(=N)O)Oc3ccccc3)cn2)cc1',
#  'CC(C)C1CC[CH]C1C(C)(C)C',
#  'CC1(c2ccc(C#N)n2-c2ccc[nH]2)CC(c2cc(F)ccc2F)C(C)(C)O1',
#  'CCCCN=c1[nH]cnc(N)c1-c1ccccc1Cn1cccn1',
#  'Cc1nn(CCC2CCc3cc(-c4cccc(C(O)=NOS(=O)(=O)O)c4)ncc32)c(C)c1',
#  'CCOC(=O)c1cc(C2CC2)c2c(N)c(C)oc2n1',
#  'COc1cc(OC)c(C2C(C)CCC(Cl)C2Cl)cc1Br',
#  'COc1ccc(Br)cc1C(CN)C(C)C',
#  'CCCCC(N)C(=O)N1CCN(C(=O)C2CC2)CC1',
#  'CCOc1ccc(S(=O)(=O)NC(C)c2n[nH]nn2)cc1',
#  'CC(CF)NC(=O)c1ccc(NCC(=O)c2cccc(C(F)(F)F)c2)cc1',
#  'CC(CC(=O)O)N=C(O)Cc1ccc2CCCc2c1',
#  'OC1CC(Oc2ccc(Cl)cn2)C1',
#  'CC1SC(=O)N(Cc2ccc(C(=O)NCc3ccccc3)cc2)C2=C1C(c1ccccc1)N=NC2c1ccccc1',
#  'Cc1nc(C)c(C(=O)N(C)Cc2c(-c3ccccc3)c(O)nc(=N)[nH]2)o1',
#  'CC1CCc2c(C1)sc(N=C(O)C1CCCCC1)c2C(=O)OC(C)C',
#  'CCCCC(C)OC(=O)c1cc(Cl)cc(I)c1',
#  'COC(=O)c1ccc(S(=O)(=O)Nc2ccc(NC(=O)C(C)C)cc2)cc1Cl',
#  'CCOC(=O)C1CN(c2cccc(C)n2)C2=C1C=C(c1cccc(NC(=O)O)c1)C(CC)C2',
#  'CCc1c(F)c(F)cc2c1NC(NC)N=C2',
#  'N#CCc1cc(F)c(C(F)F)c(F)n1',
#  'CCc1ccccc1CNCC1=CCCOC1',
#  'CC1(C)C(=O)C=C2c3c(CCC4=CC1(O)C=CC4C(=O)N2CC1CC1)n(C1CCCCC1)cn3',
#  'Cc1nc(-c2cccs2)ccc1C(O)=Nc1cccc(I)c1',
#  'CCc1nc(-c2cc3c(CCCCC3)s2)c(C(=O)O)[nH]1',
#  'CC(=O)c1cnc2CC3N(C(C)C)CC4CC43c2n1',
#  'FC(F)(F)c1n[nH]c2c1[nH]c(=NC1=NCCCN1)cc2',
#  'COc1cccc(-c2noc(C3CC(=O)N(c4ccc(F)cc4)C3)n2)c1',
#  'CN(CCO)CC(O)=Nc1nc(-c2ccco2)cs1',
#  'CNCCc1cncn1Cc1ccc2OCOc2c1',
#  'O=C1C(CC(O)=Nc2ccccc2)SC(=[NH+]N=Cc2ccccc2)N1N=Cc1ccccc1',
#  'OC(=Nc1cn(CC(F)(F)F)nc1)c1c[nH]nc1-c1ccccc1Cl',
#  'CN(Cc1ccncc1)C(=O)CC1CCC(C)(C)CC1',
#  'CCc1ccc2NC(c3ccccc3)C3C(=O)C=CC3c2c1',
#  'CCCCOCCCNC(=O)c1nn(-c2ccc(OC)cc2)c(-c2cccc(-c3ccc(OC)c(OC)c3)c2)c1',
#  'CC(C)N1C(=N)NCC12CCCOc1ccccc12',
#  'CC(C)Cc1noc(CNC(C)(C(=N)O)C2CC2)n1',
#  'CCC[NH+](CC)Cc1ccc2-c3ccccc3CC(N3CC[NH+](Cc4ccc[nH+]c4)CC3)c2c1',
#  'COc1ccc(COC(=O)c2ccc(C(=O)N(C)C)cc2)cc1',
#  'O=C(O)C(F)(F)c1ccnc(CCc2ccccc2)n1',
#  'CC1CCC(CN2CCN(C)C(=O)C2)CC1',
#  'O=C(c1ccccc1)N(Cc1ccccc1)c1nc(-c2ccc(Cl)cc2)cs1',
#  'CC(C)(C)OC(=O)Nc1ccc(-c2nc3cc4c(cc3[nH]2)NC(=O)C42CCN(c3ccc(F)cc3)CC2)cc1',
#  'COCS(=O)(=O)CC(O)=Nc1cc(Cl)ccc1-c1cccc2ccccc12',
#  'Cc1nc(-c2cc3c4C(=O)C(C(c5ccc(O)cc5)O3)C3(CCOC(C)(OC5OC(CO)C(O)C(O)C5n5cncn5)C3)Oc4c2)ccc1Oc1cccnc1',
#  'O=C(O)CC(c1ccc([N+](=O)[O-])cc1)c1nc(CCNc2ccccc2)cs1',
#  'CCCC1SC(=O)N(CC2=NC(=O)C(c3ccc(C)cc3)S2)C1=O',
#  'CC1(O)CCCN(C(=O)C2COCCO2)CC1',
#  'Cc1c(Br)sc(S(=O)(=O)NC2(CCl)CC2)c1',
#  'CCOCC(NS(=O)(=O)c1ccc(C(F)(F)F)cc1)C(=O)c1ccccc1',
#  'CCOCC1CCCN1c1c(CN(C)C)c(=O)n(-c2ccccc2)cc1C(=O)CS(N)(=O)=O',
#  'CCCN=C(O)C(C)S(=O)(=O)Cc1ccc(OC)cc1',
#  'COc1ccc2nccc(CCC(O)C3CCN(CCSc4nccs4)CC3CC(=O)O)c2c1',
#  'NCC(c1ccccc1)C1CC(=O)N1c1ccc(Cl)cc1',
#  'CCCCCCCCCCCCCCOCC(=O)c1cn(C(C)(C)C)oc1=O',
#  'CN1CC(N2C(=O)CCS2(=O)=O)CC1=O',
#  'OC(=Nc1ccccc1)C(NCc1ccccc1Nc1ccccc1Cl)c1ccccc1',
#  'O=S(=O)(CC1CCCCC1)NC1CCCCC1n1cccn1',
#  'COc1ccc(C2=NN(CC(=O)N3CCN(C(c4ccccc4)c4ccccc4)CC3)C(=O)OC2)cc1',
#  'COCCN(C(=O)c1cccc(N)c1)C(C)C1CC1',
#  'CSC(=N)c1ccnc(C2CCCN(CN(C)c3ccc4oc(O)nc4c3)C2)c1',
#  'Cc1nc(CN2CCCCC(O)(CNC3CCCC3)C2=O)no1',
#  'CN(C)C(=O)CC(O)=NN=Cc1c[nH]c2ccccc12',
#  'O=C(O)c1cccc2cccc(N=C(O)C3CC(=O)N(CCc4ccccc4)C3)c12',
#  '*CC1=C(C(C)(C)O)C=CC(CN=[N+]=[N-])C1',
#  'Cc1ccccc1C1CN(CCC(O)=NC(O)=NCc2ccccc2)C(=O)CO1',
#  'CCCCCCCCCCCCCCCCCCCCCC=CCCCCCCCCC(O)CO',
#  'COCC(=O)N1CCN(C(=O)c2c(N=C(C)O)snc2C)CC1',
#  'C=CCN=c1[nH]c(SCC(O)=Nc2ccccc2C)ncc1F',
#  'CCS(=O)(=O)CC(C)N(CCOC)CN=C(O)Cc1ccc(Cl)cc1',
#  'CC(=O)N(CCC(=O)N1CCN(Cc2ccccc2)CC1)c1cccc(C)c1C',
#  'CCC(=O)Oc1ccc(C(=O)c2c(C)cc(C)c(CSc3nccn3C)c2C)cc1',
#  'CC(N)C(=O)c1cnc[nH]1',
#  'Cn1cc(CN=c2[nH]c(C(=O)C3CCCCC3)cs2)nn1',
#  'CCOc1ccccc1N=C(O)C1CCN(C(=O)N(Cc2ccccc2)Cc2ccccc2)CC1',
#  'COc1cccnc1C(=O)[NH2+]CCN(C)C1CC1',
#  'CCCS(=O)(=O)NC1CCC(CC(=O)c2cc3nn(-c4cc(OC)cc(OC)c4)c(=O)n3[nH]2)CC1',
#  'CC1(CO)CCN(CC2CCCC2(C)C)CC1',
#  'COc1cc(C(N=C(O)CCc2c(C)nc(C)nc2O)c2nccn2C)cc(OC)c1',
#  'CCCCN1CC=CC2SC34C=CCN(c5ccccc5Cl)C(=O)C3N(C(C)C(O)=NC3CCCC(C)C3C)C(=O)C4C2C1=O',
#  'Cc1cc(CN(C)C(=O)c2ccc3cccc(N4CCCCC4)c3n2)no1',
#  'CCNC(C)c1ccccc1N=C(O)c1c(CC)cco1',
#  'CCN(C)c1ccc(C(C)NC2CCN(c3ncccn3)CC2)cc1',
#  'Cc1cc(C(O)=NCC(C)(C)O)c(C)n1C1CC1',
#  'Cc1cc(OCC(O)CSc2nnc(-c3ccccn3)n2C)ccc1',
#  'CCN=c1nc(N(C)C)[nH]c(N2CCCCCC2)n1',
#  'O=C(CC12CC3CC(CC(C3)C1)C2)Nc1ccc(C(=O)NC2CCS(=O)(=O)C2)cc1',
#  'O=C1C2CCCCC2C(=O)N1c1ccccc1Oc1ccc(Br)cc1',
#  'CC1CCN(C(=O)CCN2C(=O)C(C)N=C2O)C1',
#  'O=C1N=C(C2C=CC=CC2)C=CC1C1OC(CO)C(O)C1O',
#  'Cc1cc(NC2CCN(c3nc(NN)ncc3F)CC2)ccc1',
#  'CC[NH+](CC)C(=O)C1CCCC1S(=O)(=O)[N-]c1ccc(OC)cc1OC',
#  'Cc1ccc(C(O)=Nc2nc(-c3ccccc3)cs2)c(Br)n1',
#  'c1ccc(-c2ncccc2-c2ccc(-c3c(-c4ccccc4)c(-c4ccccc4)c(-c4ccccc4)c(-c4ccccc4)c3-c3ccccc3)cc2)cc1',
#  'O=C(Nc1ccc(-c2cnco2)cc1)c1ccc(Br)c(Cl)c1',
#  'O=C(O)Nc1ccc(Oc2ccc(C(=O)N3CCCC3)c(C(=O)N3CCC(C4=CC=C(F)CC4)CC3)c2)nc1',
#  'C=C(Br)CN=C(O)N(C)CCC=C(C)C',
#  'N=C(O)CCCNC(=O)c1ccc(-c2cnc(-c3ccc(F)cc3)o2)cc1',
#  'CCC1CCCC(C(=O)C(OCc2ccccc2)C(=O)OC2CCCC2)N1',
#  'CCC(O)=NC(C)c1nnc(SCC(=O)N2CCC(C)CC2)n1-c1ccc(OC)cc1',
#  'CN1CCC(N(C)c2c(C(=O)Nc3ccc(-c4cnco4)cc3)oc(-c3ccccc3)n2)CC1',
#  'CCc1nn2CC(NC(C)c3ccc(Cl)cc3)CCc2n1',
#  'Cc1ccc(CNC(=O)c2n[nH]c(-c3ccco3)c2)s1',
#  'CC(=O)N(C)CCN(CCN(Cc1cccc(Oc2ccccc2)c1)C(=O)c1cccc(Oc2ccccc2)c1)C(=O)c1cccc(Oc2ccccc2)c1',
#  'Cc1cn(CN2CCCC(c3nnc4ccccn34)C2)nc1',
#  'OC1=NC(c2cccnc2)NC2CN(Cc3cccc(F)c3F)CCC12',
#  'CCNC(C[Si](C)(C)C)c1c(CC)occ1',
#  'Cn1c(C2CCN(c3cnccn3)C2)nc(C2CNNC2)cc1=O',
#  'Cc1nc(CC2=NC(=C3C=CN=C3)NO2)cs1',
#  'Cc1c(O)cccc1C(O)=NCCCC1CCCCO1',
#  'COc1ccc(CN=C(O)C2CCCN(c3nnc(SCC(O)=NC4CCCCC4)c(Oc4ccc(Cl)cc4)n3)C2)c(OC)c1',
#  'NCCCOCCCCN1CCC1',
#  'O=C(c1noc(C2CC2)c1)N1CCC(O)(CN2CCCC2)CC1',
#  'CCOc1ccc(CCC(O)Oc2ccc3NC(=O)CCc3c2)cc1',
#  'COc1cccc(N=C(O)c2csc(=NC3CCS(=O)(=O)C3)[nH]2)c1',
#  'CC1CCCN(c2ccc(S(=O)(=O)CNC(=O)c3ccc(OCC4CC4)cc3)cc2)C1',
#  'CCC(C)(CC(O)=NC1CCN(C(=O)OC(C)(C)C)C1)CC(C)C(=O)O',
#  'O=[N+]([O-])c1ccc(-c2nc3c(CCCC3)c(=[NH+]C3CCCCC3)[nH]2)cc1',
#  'Fc1ccc(-c2c3[nH]cccc-3nc2)c(C(F)(F)F)c1',
#  'CCOC(=O)C1CCc2c(C1)c1ccccc1[nH]2',
#  'Cc1c(C#N)c(O)ncc1-c1cccc(F)c1',
#  'Nc1nccnc1C(O)=NC1CCN(Cc2ccccn2)CC1',
#  'N=c1[nH]c(C2CC2c2ccc3ccccc3c2)nc2ccccc12',
#  'CCC1OCCC1C(O)=Nc1c(C)n(Cc2ccccc2F)nc1C',
#  'CC1CC(NCCc2cscc2)CS1',
#  'C#CCNCCCOc1ccc(C(=O)OCC)c(Br)c1',
#  'CC(C)Cc1noc(C(C)OC(=O)c2ccc(N)c([N+](=O)[O-])c2)n1',
#  'CCOC(=O)c1cc(S(=O)(=O)NC(C)(C)C)c(N)s1',
#  'CC1CCC(c2ccc(OC(C)(C)C#N)cc2)CC1',
#  'CCOC(=O)c1c(C)cnn1-c1coc2ccccc12',
#  'Cc1cc(CC(=O)OCC(=O)Oc2ccc(OCc3ccccc3)cc2)c(C)n1Cc1ccccn1',
#  'CC=C1CCC2C3CCC4=CC(=NO)CCC4C3CCC12C',
#  'CC(=O)C1CCN(NCc2cc3c(cc2O)OCO3)CC1',
#  'CN(C)c1ccc(C2CCC(O)(C(F)(F)F)C23C(=O)N2CCCC2C(O)C3c2ccc(F)cc2)cc1',
#  'OCCCC1CC12CCN(CO)CC2',
#  'CC(O)=Nc1ccc(S(=O)(=O)N2c3ccccc3Sc3ccccc32)cc1',
#  'COc1ccccc1-c1ccc(C(O)=NC(C(=O)O)n2cccc2)cc1F',
#  'CC(C)(C)c1c(Br)cc(N)c(N)c1OC(F)(F)F',
#  'Cc1ccc(C2(c3cc(C)ccc3C)CC(=O)N(CC(=O)O)C2=O)c(C)c1',
#  'CC(C)(C)c1noc(CCCC(O)=Nc2ccccc2C(=O)N2CCOCC2)n1',
#  'CCC(C)Sc1ccc([N+](=O)[O-])c(C(=O)OC)n1',
#  'COc1ccc(C2C(c3ccc(C)c(C(O)C(C)(C)C)c3)C(=O)C(=O)N2CCCN2CCOCC2)cc1',
#  'CCc1ccc(CC(NC)c2ccccc2[N+](=O)[O-])cc1',
#  'O=C(OCC(=O)N1c2ccc(S(=O)(=O)O)cc2Sc2cc(S(=O)(=O)O)ccc21)c1ccc([N+](=O)[O-])cc1',
#  'N#Cc1ccc(Cl)c(S(=O)(=O)Nc2csc(C3CCC3)n2)c1',
#  'c1ccc(SCCCN2CCNCC2)cc1',
#  'O=C1Nc2cc(O)ccc2OC1CCO',
#  'Cc1nc(Sc2ccc(NC(=O)C=Cc3cncn3C)c(C)c2)ncc1',
#  'O=C1N=c2ccc(NC(=O)c3ccco3)cc2=NC1=C1NNc2ccccc12',
#  'C=CC(CCCC(=O)OCCCC)N(C)C',
#  'CS(=O)(=O)c1ccc(Cc2nnc(N=C(O)CCN)s2)cc1',
#  'Cc1ccc(CN2CCC(CN(C(O)=NC3CCCC3)C3CC3)CC2)cc1',
#  'C=CCCC(=O)c1ccc(CN(C)C(=O)OC(C)(C)C)o1',
#  'CS(=O)(=O)OCC1OC(Oc2ccc(O)cc2)C(O)C1O',
#  'Fc1ccc2CN(Cc3cccs3)CC(OCc3ccccc3)c2c1',
#  'COCc1cccc(COCC(=O)n2ccc(=O)n(C)c2=O)c1',
#  'COCC(=O)c1ccc(C#Cc2cccc3c2Cc2cc(O)cc(NC(O)=NC4CCOCC4)c2-3)cc1',
#  'CC1CCN(C(C)C[NH+]=C(O)N2CCN(CC3CCOC3)CC2)CC1',
#  'CCOC(=O)C1=CC(Cc2ccc(C)cc2)NN1',
#  'CCc1nn(Cc2ccc(I)cc2)c(CC)c1CC#N',
#  'COc1cccc(C(O)=[NH+]C(S)=Nc2ccccc2OCCOc2ccccc2)c1',
#  'CC(C)CCc1ccc(C(=O)CC(c2ccccc2)C2CCCCN2c2c[nH]nc2)cc1',
#  'CCN(C)c1ccc(CNc2cccc(N3CCCC3=O)c2)cc1',
#  'C=CCN1C(=O)C2C(NC3N(CC4CC4)CCCN23)N(C)C1=C(C)CCc1ccncc1',
#  'O=C(O)C1(C(=O)N2CCN(Cc3ccc4OCOc4c3)CC2)CCOCC1',
#  'CC1CN(C(=O)C(=O)Nc2cccc(C(O)=NC3CC3)c2)CCS1',
#  'COCCOc1ccc(C(=O)N2CCN3c4c(CC3C2)scc4)cc1',
#  'Cc1ccc(S(=O)(=O)N(c2c(C)[nH]c(C)cc2=O)C2CC(Cn3cncn3)C(c3ccc(Cl)c(C)c3)=NO2)cc1',
#  'O=C(Cc1cccc(Br)c1)N1CCC(Br)C1',
#  'Cc1cc(Cl)ccc1C1CCN(CN)C1',
#  'COCCN(CCOC)C(=O)c1ccc(N2N=C(O)CCC2=O)cc1',
#  'COCC(=O)N(Cc1cc(OC)cc(OC)c1)C(=O)CCCC(O)=Nc1ccccc1',
#  'CC(C)(C)OCC(=O)NS(=O)(=O)c1ccc2[nH]c(=O)c(=O)[nH]c2c1',
#  'CC(O)CNC1(Cc2cccc(Cl)c2)CCC1',
#  'COC1(Cc2cc(-c3nn(C)c(C)c3C(F)F)c3NC(C=Cc4ccnc(-c5csc6ccccc56)c4)NS(=O)(=O)n3c2=O)COC1',
#  'CC1=CC(=O)C(=CNNC(=O)c2ccncc2)C=C1Br',
#  'CC(c1cccc(Br)c1)N(C)Cc1cc2c(cc1Br)OCO2',
#  'CC(O)(CNCc1ccc(Br)s1)c1cccs1',
#  'CCc1ccc(F)cc1N=C(O)N(CC)CC1CCCO1',
#  'CC(c1cccnc1)N(C)C(=O)c1cnc(OC2CCOC2)c(Cl)c1',
#  'CN(c1ccccc1)c1ccc(C(=O)NC(C(=O)O)C(C)(C)C)cn1',
#  'CC(C)(C)c1ccc(C(O)=NN=C(O)c2cccc(OCC(O)=Nc3ccccc3F)c2)cc1',
#  'Cc1ccc2c(CCN=C(O)Cc3ccc(S(=O)(=O)NCc4ccco4)cc3)c[nH]c2n1',
#  'CCOCCCN=C(S)N=c1cc(C)n(Cc2ccccc2Cl)[nH]1',
#  'CCCNCC(c1cc2cc(Br)ccc2o1)c1cccnc1N',
#  'Cc1ccc(S(=O)(=O)N(C)C(=O)c2cccc(-c3ccccc3)c2)cc1',
#  'CCC1CCCN(CCC(=O)c2cccs2)C1',
#  'CC(NC1COCC1c1ccc(F)cc1)c1ccc(S(N)(=O)=O)cc1',
#  'COc1ccc(C)cc1C1CCNC1C(=O)O',
#  'Cc1ccc(NC(=O)c2cccnc2N2CCCCC2)cc1',
#  'CCC1CN(C(=O)c2ccccc2Br)CC(C)O1',
#  'CN(C(=O)c1c(N)ccs1)c1cccc2ccccc12',
#  'COc1ccc(C(O)=NCC(=CF)C2CCC2)c(NC(N)Cc2ccc(C)cc2)c1',
#  'CCOC(C)C(O)=Nc1cccc(C#N)c1',
#  'CCOC(=O)C(C)OC(=O)c1cc(S(=O)(=O)CC)ccc1F',
#  'CCN1CCN(CC(C)CNC(=NC)N2CC(C)SC2C)CC1',
#  'O=C(C1CC1C(=O)N(Cc1ccccc1)CC1CCCCC1)N1CCCC1',
#  '[CH2]C(CC=C)O[Si]1(C)CCCCC1C',
#  'CC1(CN=c2[nH]c(Cl)nc3c2ccn3C23CCC(CC2O)C3(C)C)CC1',
#  'COc1cc(NC2(c3ccc(F)cc3F)COC2)cc([N+](=O)[O-])c1',
#  'N#CCN=C(O)CNCC1=CCCOC1',
#  'CN(C)CCOc1cccc(CN=c2[nH]nc(-c3ccco3)o2)c1',
#  'CCc1cncn1COC(=O)c1cc(S(=O)(=O)NC)cn1C',
#  'Cc1cc(COCC(=O)SCc2nnc3n(C)c(=O)c4ccccc4n23)ccc1',
#  'CC(C)(C)C(O)=NNS(=O)(=O)Cc1ccc(F)cc1Br',
#  'CC1=CCCC(O)(C(C)c2ccccc2)C(=O)OC1',
#  'COCN=C(O)c1cc(N)ccc1-c1cnc[nH]1',
#  'C=CC(C)C(N)CN1C(=O)c2ccccc2C1=O',
#  'CCc1cccc(C)c1N=C(O)c1c(C)oc(S(=O)(=O)N2CCCC2)c1',
#  '[N-]=[N+]=NC(c1ccccc1)S(=O)(=O)OS(=O)(=O)OC(=O)O',
#  'CCc1cccc(NC2=NC(C)CS2)c1',
#  'CC(c1nc2ccccc2s1)N(C)C(=O)CN1CCCC1c1cscc1',
#  '[N-]=[N+]=NCCNc1ccc(C(O)=NC2COc3cc(F)c(I)cc3N=C2O)c(F)c1',
#  'CCOC(=O)c1c(C)n(-c2cccc(Cl)c2C#N)nn1',
#  'CC1CN(C(=O)c2cncc(F)c2)CCN1',
#  'Cc1ccc(CC(O)=NC(C)CC(=O)N2CCCC2)cc1C',
#  'c1cncc(NC2CCc3ccccc3OC2)c1',
#  'CCCC1CCCN(Nc2cc(C)c(Br)c(C)c2)CC1',
#  'CC(CN=C(O)Nc1ccc(F)c(N2CCOC2=O)c1)N(C)c1ccccc1',
#  'COC(=O)C12CN(S(=O)(=O)c3ccc(F)cc3)CC1C1CC2OC1C',
#  'Cc1ccc(Cc2cn(CO)nn2)c(C)c1',
#  'COc1ccccc1C(=O)N1N=C(C2CC2)CC1c1ccc(C#N)cc1',
#  'Cc1ccc(CN2C(=O)C(=O)C(=C(O)c3nnc(C)o3)C2c2ccccc2F)cc1',
#  'CCCOc1ccc(C(O)N2C(=O)C(=O)C(CC3CCCO3)C2c2ccc(Br)cc2)cc1',
#  'CCCc1c(O)ccc2c1OC(C)(c1ccc(Oc3ncccc3C)cc1)CC2=O',
#  'CC(c1ccc(Br)cc1)(c1ccc(Br)cc1)c1ccc(Br)cc1',
#  'CCNc1cccc(CC(=O)CC2CCS(=O)(=O)C2)n1',
#  'CCOc1ccc(OC)c(C2C(c3cccc(Cl)c3)=C(O)C(=O)N2c2cccc(C)c2C)c1',
#  'CCOC(=O)CC(=S)SC',
#  'CCOC(=O)C1=CCCC(C)=C(C=O)Cc2cccc(c2)CCC1',
#  'CN=C(O)CSc1nnc(CS(=O)(=O)c2ccc(C)cc2)n1CCc1ccccc1',
#  'CCN(CC)C(=O)CSc1nc2ccccc2c(=O)n1-c1ccccc1OC',
#  'COc1ccc(CN=C(O)N2CCCC(C(O)=NCCN)C2)c(Cl)c1',
#  'NC1CCOCC(CC2CC2)C1',
#  'CCOC(=O)N1CC[NH+](CC(O)COC(C)c2ccccc2)CC1',
#  'CC(NS(=O)(=O)c1ccc(S(N)(=O)=O)cc1)c1ccc(Br)cc1',
#  'Cc1cc(C)cc(C(O)=NC(C)CC(=O)Nc2ccc(Oc3ccccc3)cc2)c1',
#  'CC(O)=Nc1nc(CNc2cccc(N=C(O)c3ccccc3)c2)cs1',
#  'O=Cc1n[nH]c2ccc(-c3ccccc3Cl)cc12',
#  'Clc1ccc2c(c1)C(c1ccccc1Cl)NCc1nnc(-c3cccs3)n-21',
#  'COCC(C)OCC(C#N)(NC(C)CCCC(C)C)c1ccccc1',
#  'C=CCN1C(=O)C(c2ccc(COC)cc2OC)SC1=NS(C)(=O)=O',
#  'COCCOCC(=O)NC=Cc1c(C(C)c2ccccc2)ccc2ccccc12',
#  'CCCC1(N)CCCC12OCCO2',
#  'CCc1ncc(C(O)=NC(CC)CC(=O)O)cn1',
#  'C=CS(=O)(=O)N(CCCCCl)C(=O)c1ccccc1Br',
#  'OC1CNCC1CNC1OC2OCC2C(O)C1O',
#  'CC(CO)C(C)N=C(O)N(C)c1ccccc1Cl',
#  'CN1CCC(CC2CCN(C(=O)c3cc(O)ns3)CC2)(c2ccccc2)CC1',
#  'Cc1ccc2c(c1)N(C(=O)Cc1ccccc1F)CCCN2C(=O)c1cccc2ccccc12',
#  'CN=C(O)C1CNCCN1C(=O)c1cccc(Br)n1',
#  'Cc1nc2ccc(NCc3ccccc3Cl)cc2[nH]1',
#  'COC(=O)C1(C(=O)OCCSC)SC2C(Sc3ccccc3)C(=O)N2C(C(C)=O)=C1c1ccccc1',
#  'CCC(N)C(Nc1c(F)c(F)c(F)c(F)c1F)C1CCCCC1',
#  'CCc1ccc2-c3ccccc3C(C(C)O[Si](c3ccccc3)(c3ccccc3)c3ccccc3)([Si](c3ccccc3)(c3ccccc3)c3ccccc3)c2c1',
#  'COc1ccc(-c2c(-c3ccnc(NC(=O)c4ccc(F)cc4)n3)n(-c3ccc(F)c(Cl)c3)cn2)cc1',
#  'Cn1cc(N=C(O)C2CC3CCCCC3N2C(=O)c2cscn2)c(-c2ccccc2)n1',
#  'Cc1csc(C(=O)C(C#N)c2cn(C(C)C)nc2)n1',
#  'Cc1ccc(O)c(C(O)=NN=C(O)c2ccc(-c3ccc(F)cc3)cc2)n1',
#  'Cc1nc(NC(C)(C)C)nc(C(=O)NCc2cccc(Br)c2)c1',
#  'CC(C)(C)N=C(O)CN=C(O)c1ccc(OC2CCCC2)c(-c2ccc(OC(F)F)cc2)c1',
#  'CN(C)CCCN1C(=O)C(=O)C(=C(O)c2ccccc2)C1c1ccc(Cl)c(Cl)c1',
#  'CC(C)N(CCO)Cc1noc(CCc2ccccc2)n1',
#  'CCC(CCOC(C)=O)C1C(O)C(C)(C)OCC1(C)C',
#  'CCCCOC(=O)C1CC(c2nc(=O)n(C3CC3)[nH]2)(c2nc(=O)n(C(F)(F)F)[nH]2)NN1',
#  'CCCCN(C(=O)C(C)OCC1CC1)C1CC1',
#  'Cc1ccc(OCC(=O)O)c2c1oc(=O)s2',
#  'CCC(C)N=C(O)C(C)N(Cc1ccc(F)cc1)C(=O)CCCN1C(=O)c2c3c1cccc3ccc2',
#  'CC(C)C(CS)C(=O)C1CCCN(c2ncc(C(O)=NC3CC3)s2)C1',
#  'CCOC(=O)C1(Oc2ccccc2OC)OC=CO1',
#  'CC1CN(C)CC(CCc2ccc3ccc4ncccc4c3n2)O1',
#  'CCC1CCCCN1CC(=O)Sc1n[nH]c(=NN=C(C)c2ccc(C=NNc3nc4ccccc4s3)cc2)n1N',
#  'CCN(CC)C(=O)C(=O)NCCCOCc1ccccc1',
#  'CCC1CC2C3C(=O)N(c4csc(N5CCOCC5)n4)C(=O)C3CC(CC)C2C2(Cl)C(Cl)=C(Cl)C1CC2Cl',
#  'CC=CC(C)=CC(O)=NC',
#  'C=CC(=O)N1CC(C)N(c2nc(=O)n(-c3nccc(C)c3C(C)C)c3nc(-c4c[n+]([O-])cc5ccccc45)c(F)cc23)C(C)C1',
#  'CCCN(CC1CC1)c1ccc(C(C)O)cn1',
#  'Cc1cc(C)c(CC[NH2+]OC(C)(C)C)c(C)c1',
#  'COC(=O)C(=O)S(=O)(=O)c1c([NH2+]c2ccc(C(CN=C(O)Nc3ccc(Cl)cc3Cl)CC(C)C)cc2)sc2cc(OC)ccc12',
#  'COc1cc(C2CCCN2C(=O)C2CSCN2C(=O)C2CCCN2C(=O)C2CCCC2)c(N)cc1NC(=O)CN',
#  'CCC1CN(CCSc2nnc(-c3c[nH]c4ccccc34)n2-c2ccccc2OC)CCO1',
#  'CCCOc1cn2cc(C(C)(C)N)ccc2n1',
#  'O=C1COc2ccccc2C2(C(=O)N3CCOCC3C3CCCO3)CCCN12',
#  'O=S(=O)(c1cccnc1)C1CCN(NC2CCCCC2)CC1',
#  'CCC(C)NC(C(=O)O)c1ccc(OC)cc1',
#  'Cc1ccc(CNc2ccnn2C2CCN(C)CC2)cc1C',
#  'O=C(NCc1noc(-c2ccc(F)cc2)c1)c1ccco1',
#  'CCCOc1ccc(-c2ccc(C3=C(O)C(=O)N(OCC)C3c3cc(Br)ccc3F)cc2OCC)c(C)c1',
#  'COc1ccc(CCc2nn(-c3ccccc3)c3c2c(=O)n(C)c(Cc2ccccn2)n3)cc1',
#  'CCN1CC(O)=Nc2ccccc21',
#  'COCCc1nnc(-c2ccncc2)n1SCC(O)=Nc1ccc2c(c1)C(=O)c1ccccc1-2',
#  'CC1CN(C(=O)C(C)Nc2ccc(N)cc2)CCO1',
#  'CCCCCC(=O)N(CCc1ccc(OC)c(OC)c1)CCN(C)C',
#  'O=C(OCc1ccccc1)C1CC2CC1C1C(=O)N(c3ccc(F)cc3)C(=O)C21',
#  'Cn1ccnc1CNC1CS(=O)(=O)CC1N1CCCC1',
#  '*C#Cc1c(F)cc2c(-c3cc(Oc4cccc(C(F)(F)F)c4)cc(CCC4(O)CCN(c5ncc(OC)c(C)n5)CC4)c3)ccnc2c1',
#  'Cc1nc(Oc2cccnc2)nc(CC(C)N)c1',
#  'C=CCC1CC(OC=CC(=O)O)C1(C)C',
#  'CN(CC(O)c1cccc(C(F)(F)F)c1)C1CCCC1',
#  'CCc1nc(C(C)NC)c(C(=O)O)s1',
#  'O=C1N=C(O)C(C2CC3CCC2C3)C2CCCCCC12',
#  'C=C(CC(=O)OC(CCCCC(=O)O)OC(=O)CC(=C)C(=O)OCc1ccc([N+](=O)[O-])cc1)C(=O)OCc1ccc([N+](=O)[O-])cc1',
#  'N#CC1=C(C2CC2)Oc2c(c3nc(-c4noc(-c5ccccc5)c4)nn3cn2)C1c1ccccc1Cl',
#  'CC(=O)N(C)Cc1ccccc1CCC(C)N=C(O)Nc1ccc(Br)cc1',
#  'Cc1ccc(C(=O)NCCN=C(O)C(C)N2CCCCC2C)cc1C',
#  'OC(=Nc1ccc(CN2CCCC2)cc1)c1ccc(-c2nc(C3CC3)no2)cc1',
#  'COC(=O)C(C)(C)CN=C(O)C(C)(C)c1ccc(F)cc1',
#  'Cc1c2cc(CN3CCN(C(=O)c4cc[nH+]cc4)CC3)c(N3CCN(C(=O)OC(C)(C)C)CC3)nc2n[nH]1',
#  'NC=CC=NN=C(O)c1nc(O)nc(-c2cccnc2)c1',
#  'COCC(C)(O)CNCC1CCCS1(=O)=O',
#  'CC1(N)COCC1=Cc1ccc(F)nc1',
#  'CCN(CC)Cc1cccc(-n2c(SC(C)C(=O)N3CCOCC3)nc3ccccc3c2=O)c1',
#  'COc1ccc(N2CCN(C(=O)CCC(CC(O)=NO)c3ccc(C(C)C)cc3)CC2)c(Cl)c1',
#  'CC(C)(C)OCC(=O)Nc1cccc2nccn12',
#  'O=C(O)c1c(-c2ccccc2)c2cc(Br)ccc2nc1O',
#  'CCc1ccc(CCCC(O)N2CCC3(CC2)CN(c2ccc(F)cc2)C(=O)CO3)cc1',
#  'CCCCN=C(O)C(c1ccc(O)c(OC)c1)N(CCC)C(=O)c1ccccc1',
#  'COc1cc2c3C(=O)C(C2)C(O)(SC(C)(C)C)C(=O)c3c1',
#  'Cc1c(OCCOc2ccccc2)c(C(O)=NC2CCCN(C(C)CC=O)C2)ccc1',
#  'Cc1cc(OCC(C)N=C(O)C2CC(=O)N(C(C)C)C2)ccc1',
#  'CCN(CCN)c1ncnc2c1c(Br)nn2C',
#  'O=C(O)C12CCCCCC1C1CCC2C1',
#  'OCCCC1CCCN(c2ccncn2)CC1',
#  'CCOCC(=O)c1ccc(Oc2ccc(I)cc2)c(N=S(C)(C)=O)c1',
#  'O=C(O)C1Cc2ccccc2CN1CCc1ccccn1',
#  'O=C1C(=Cc2cccc(F)c2)Oc2cc(OCc3ccccc3F)ccc12',
#  'Cc1ccc(NN=C(O)N(C)Cc2ccccc2O)nc1',
#  'Oc1c2ccccc2nc(CNc2cc(Cl)cc(Cl)c2)n1',
#  'CC(C)c1csc(C(=O)N(Cc2cccs2)c2ccc3OCCOc3c2)n1',
#  'Cc1cc(=O)n2c(-c3ccc(NS(=O)(=O)c4ccccc4)cc3)csc2n1',
#  'CC1=C[C](c2cc(-c3ccc(F)cc3)c(C)o2)OC1',
#  'CC(C)(C)NCc1cccnc1Sc1cccc(F)c1',
#  'CC(=O)OCC(C)C(=O)c1cc(-c2ccnc(OCCc3ccccn3)c2)c2ccccc2n1',
#  'CCN=C(O)c1nc(-c2ccc(C(=O)N(C)C)cc2)cs1',
#  'O=C(O)CSc1ncc(-c2ccccc2)n1C1CCCc2cccnc21',
#  'OC(=NN=Cc1c(OCc2ccccc2F)c2ccccc2cc1)C(F)(F)F',
#  'Cc1ccc(NC(=O)c2ccc(NC(=O)C3CCN(C(C)C(O)=Nc4cccc(C(O)=Nc5cc(F)ccc5F)c4C)CC3)cc2)cc1F',
#  'CSCCCCN=C(O)NCc1ccco1',
#  'CCOc1ccccc1N1CCN(C(O)=NC(C)C(O)=NC2c3ccccc3-c3ccccc32)CC1',
#  'COCCNCCC(C)(C)c1ccc(C(C)(C)C)cc1',
#  'CCN(C(=O)c1cccc2c1NC(c1ccc(Cl)cc1)C1CC=CC21)c1ccccc1',
#  'COc1ccc(CCNCc2c(C)nc(O)s2)c(F)c1',
#  'COc1ccc(CN2CCc3cc(OC)c(OC)cc3C2C)c(OC)n1',
#  'CCN(C(S)=Nc1ccc(Br)cn1)C(C)C',
#  'CCCCCCCCCCC(N)c1ccc(C)c(F)c1',
#  'CC(=O)CCCCCCCCCC(=O)OC1CCCC1',
#  'Cc1nn(C)cc1S(=O)(=O)NCC(C)(O)Cc1ccccc1Cl',
#  'CC=[SH](Cl)(Cl)c1ccc(-n2ncc3c2[nH]c(C2CCC(N(C)CC(=O)O)O2)n3)cc1',
#  'CCCC1CN(C2CCCC(C)(C)CC2)C(C(C)C)CN1',
#  'COc1ccc2oc(C(=O)N3CCN(C(=O)c4ccc(F)c(F)c4)CC3)c(C)c2c1',
#  'CC(=O)c1ccc(N=C(O)c2nnc(-c3cccc4ccccc34)o2)cc1',
#  'CCc1c(C(=O)C2COCCN2c2n[nH]cn2)snn1',
#  'Cc1nc2ccc(N3C(=O)C(C)(c4cccc(Cl)c4)N=C3O)cc2[nH]1',
#  'CC(C)CC(N)C(O)=NC1CCCc2c1cnn2-c1ccc(F)cc1',
#  'CN(CCOc1ccc(Cl)cc1)C(=O)C=Cc1cc(Cl)c2OCOc2c1',
#  'CCCCC(O)=Nc1ccc(C(=O)OCCc2ccccc2)cc1N=C(O)C(c1ccccc1)c1ccccc1',
#  'NC(Cc1ccc(F)cc1)c1cc(Cl)ccc1Cl',
#  'O=C1C(=O)N(Cc2ccccn2)C(=O)N1CC(O)=NCc1cccs1',
#  'Cc1nc2c(c(Nc3cccc(Cl)c3Cl)n1)c1c(CCCC1)s2',
#  'CC(CO)NS(=O)(=O)c1ccc(Cl)cc1N',
#  'CC1CCC(C(=N)O)CN1CCCC(=O)c1ccccn1',
#  'CN(C)CCSc1n[nH+]c2CN(CCc3ccccc3)c3ccc(F)cc3-c2n1',
#  'CC(C)(c1ccc(C(=O)NC2C(=O)N3C(C(=O)O)=CCSC23)cc1)c1cccc(OCc2cccc3ccccc23)c1',
#  'CC1CC2C(O)=NC(=O)N2C(C(O)=NC2CC(=O)N(CC(F)(F)F)C2)C1',
#  'C1=CCN(C2CCCC2)CC1',
#  'CCc1nc(OC(F)(F)F)c([N+](=O)[O-])cc1N',
#  'COc1cccc(CCC(O)=NN2CCCCC2)c1',
#  'CCN(CCC(=O)O)C(=O)C1CC(C)(C)C1',
#  'CON=C1CN(C2CC(O)C(COC(c3ccccc3)(c3ccc(OC)cc3)c3ccc(OC)cc3)O2)C(=O)N(CC(O)=Nc2ccccc2)C1=O',
#  'CCS(=O)(=O)c1c(NC(C)C)snc1N',
#  'CC(C)OCCCSc1ncc(S(N)(=O)=O)[nH]1',
#  'COc1ccc(-c2csc(C(C)N)n2)c(F)c1',
#  'CCN(CC)C(=O)C1(c2ccccc2)CCN(C(C)OC)C1c1ccc(OCCCCSC(c2ccccc2)(c2ccccc2)c2ccccc2)cc1',
#  'COC(=O)CC(N)c1ccc([N+](=O)[O-])cc1',
#  'CCOCC(C)Oc1c(CN2CCC2)n2ccccc2c1C(=O)OC',
#  'Cc1cc2nc(C(=O)O)c(N=Nc3ccc(C)c(C)c3)n2cc1',
#  'CCCN(Cc1cccnc1)C(=O)C(=O)N=c1[nH]occ1CC',
#  'OC(=NC1CCc2n[nH]cc2C1)NC1C2CC3CC1CC(c1ccncc1)(C3)C2',
#  'CC(c1ccc(-c2ccc(O)cc2F)cc1)N1CCCCC1C(=O)O',
#  'Cc1ccc(C(C)N(C)CC2=NC(=O)C3SC=CC3=N2)o1',
#  'CC(C)(C)OC(=O)N1CCC(N=C(O)C2CCCN2Cc2ccc(F)cc2Cl)CC1',
#  'Cc1c(C)nc2c(C(O)=Nc3cnc(-c4cccc(F)c4)nc3)cc(F)cc2n1',
#  'CN(C)c1nc2cc(S(=O)(=O)SCc3ccc4nc(C(F)(F)F)[nH]c4c3)ccc2o1',
#  'COc1ccc(C(=O)N2CCOCC2)c(S(=O)(=O)Nc2ccc(C)cc2F)c1',
#  'NS(=O)(=O)C(O)=Nc1ccc(CC2C=CC(Cl)C=C2F)c(F)c1',
#  'CCC(O)=Nc1nc(C2CN(CN(C)Cc3ccc(-c4ccc(F)cc4)cc3)CCN2)ccc1',
#  'O=C(c1cccnc1)N1CCC(c2cccc(Cc3ccccc3F)n2)CC1',
#  'CC(CC(O)=NC1(C(O)=NS(=O)(=O)C2CC2)CCCCC1)C1CCNCC1',
#  'OCCCNCc1ccc2nc(OC(O)=NC3(C(c4ccccc4)(c4ccccc4)c4ccccc4)CCCC3O)[nH]c2c1',
#  'CCCc1n[nH]c(-c2ccc(Cl)cc2)c1OC',
#  'O=C(NNC(O)=NCc1cccnc1)c1ccc([N+](=O)[O-])cc1',
#  'COc1ccc(OCc2csc(CNCC(C)c3nccs3)n2)cc1',
#  'N#CC1=C(N)OC2N=NC(c3ccccc3)=C2C1c1cc(Br)cc(Br)c1',
#  'CCOC(=O)C1=NN(c2cccc(F)c2)C2(S1)SC(c1ccccc1)c1ccccc12',
#  'CCC(C(=O)N(C)C(C)C)c1cc(C)cc(C)c1',
#  'CN=c1[nH]c(NC2(c3ccc4nc(O)oc4c3)CC2)ncc1-c1n[nH]cn1',
#  'COc1ccc(C([O-])N2C(=O)C(=O)C(Cc3cccnc3)C2c2ccc(Cl)cc2Cl)c(OC)c1',
#  'CCCCC(NCC)c1c[nH]c2ncc(-c3c(C)[nH]ccc3=NC(C)(C)C)cc12',
#  'CCN1CCN(CC(C)C)C1=O',
#  'CCCCCCN(OC(O)=NC(CCC(=N)O)C(=O)C(C)(C)C)C(C(O)=NC(C)CCC)C(CC)CC',
#  'O=C(CC(N=C(O)c1ccccc1)c1ccccc1)OCC(O)=Nc1cccc2ncccc12',
#  'CCN(C(=O)c1cc(-c2ccccc2Cl)c2ccccc2n1)C1CCS(=O)(=O)C1',
#  'c1cncc(-c2noc(C3CCOCC3)n2)c1',
#  'O=C(Nc1ccccc1C(=O)C1CN(c2ccccc2)C(C(O)=NC2CCCCC2)CO1)c1ccc(F)cc1',
#  'CCCC(=O)C(c1ccc(C(=O)NCCC(=O)O)cc1)N1C(=O)C(c2cc(F)c(Cl)c(F)c2)=NC12CCC(C(C)(C)C)CC2',
#  'COCCCN=C(O)c1c(C)c(C(=O)CCN=C(O)c2cscc2)c(C)[nH]1',
#  'CCOc1ccc(Br)cc1CN1CCCCC(NC)C1',
#  'O=C1COC(CN(Cc2ccc(Cl)cc2)c2ccccn2)CN1C(c1ccccc1)(c1ccccc1)c1ccccc1',
#  'OC(=NC1CCN(CC(F)F)CC1)c1cccnc1Cl',
#  'CC(C)c1nsc(Br)c1Br',
#  'Cc1ccc(C(=O)C2CCC(c3cccc(P(=O)(O)O)c3)O2)cc1[N+](=O)[O-]',
#  'O=NC=CN(N=C(O)COC(=O)c1ccc(Oc2ccccc2)cc1)c1ccccc1',
#  'COCc1ccccc1CC(=O)OCc1cc(Cl)ccc1OC',
#  'Cc1c(C(=O)N(C)CC(C)(C)O)nc(-c2cccc(C(F)(F)F)c2)o1',
#  'CCNc1ccc(C(=O)NCc2cccc(F)c2)cc1',
#  'CCN(CC)C(=O)CN(C)S(=O)(=O)c1ccc2c(c1)sc(=O)n2CC',
#  'CC(C)C(N)C(=O)N(C)Cc1cccc(Br)c1',
#  'Nc1nccnc1C(O)=Nc1cnccc1OC1CCC1',
#  'CCc1c(N=C(O)C(C)Sc2nnc(-c3cccnc3)n2-c2ccccc2F)c(CC)ccc1',
#  'COC1CC(C(=O)N2CCCC2)N(S(=O)(=O)N2CC3(CCO3)C2)C1',
#  'CC1c2c(CCN1CC(=O)c1cccc(C(F)(F)F)c1)scc2',
#  'C=C=C1C=C[C](CO)C=C1',
#  'O=C1C2CCCCC2C(=O)N1CN=C(O)Cc1cnc[nH]1',
#  'CCc1nn(C)c(NC(=O)C2CCCN2C(=O)N(CC)CC)c1',
#  'CCCCC1NC2(CCCCC2)C(=O)N1SCc1noc(-c2ccc(Cl)cc2Cl)c1',
#  'Cc1nc(CN2CCN(C(=O)C3CC(=O)N(CC(C)C)C3)CC2)cs1',
#  'CC1CCCN(C(=O)c2ccc(N=C(O)c3ccncc3F)cc2)C1',
#  'CCOc1ccc(NCC(=O)C2CCCN2C(=O)N(C)Cc2nocn2)cc1',
#  'Cc1ccc(OCCN=C(O)Nc2ccnn2C2CCCC2)cc1',
#  'CC(C)N(C(=O)C(C)P(=O)(O)O)C(C)C',
#  'COCN=C(O)C(C)c1ccc(OCCOc2ccccc2)cc1',
#  'COc1cc([N+](=O)[O-])ccc1N=C(O)N(C)CCOCC1CC1',
#  'Cc1c(NC(=O)C(=O)NCCc2cn(-c3ccccc3)nc2)c(C)ccc1',
#  ...]

# %%
# 步骤1：读取所有文件内容并合并
file_paths = glob.glob("/data1/yzf/fragmlm/output/small_complete_answer_*")  # 修改为你的文件路径
file_paths
# Out:
# ['/data1/yzf/fragmlm/output/small_complete_answer_5',
#  '/data1/yzf/fragmlm/output/small_complete_answer_1',
#  '/data1/yzf/fragmlm/output/small_complete_answer_3',
#  '/data1/yzf/fragmlm/output/small_complete_answer_4',
#  '/data1/yzf/fragmlm/output/small_complete_answer_7',
#  '/data1/yzf/fragmlm/output/small_complete_answer_6',
#  '/data1/yzf/fragmlm/output/small_complete_answer_9',
#  '/data1/yzf/fragmlm/output/small_complete_answer_8',
#  '/data1/yzf/fragmlm/output/small_complete_answer_2',
#  '/data1/yzf/fragmlm/output/small_complete_answer_0']

# %%
all_smiles = []

for file_path in file_paths:
    with open(file_path, "r") as f:
        lines = f.readlines()
        all_smiles.extend([line.strip() for line in lines if line.strip() != ""])

# 步骤2：创建DataFrame
df = pd.DataFrame({"SMILES": all_smiles})

# 可选：去重（如果需要）
df = df.drop_duplicates(subset=["SMILES"])

# 查看结果
print(f"Total SMILES: {len(df)}")
df
# Out:
# Total SMILES: 10000
#                                                  SMILES
# 0                         ['*c1cccc(F)c1', '*C1CCOCC1']
# 1     ['*CC(N)C3CC3', '*S*', '*c1nc2ccccc2c(=O)n1*',...
# 2        ['*OC', '*CC*', '*O*', '*c1c(C)c(=O)c(C)cn1C']
# 3     ['*C(=O)C1(C(=O)N2CCN(Cc3ccncc3)CC2)CCCC1', '*...
# 4     ['*CC(O)=NC[C@H](C(O)=NC)N1CCc2sccc2C1', '*O*'...
# ...                                                 ...
# 9995  ['*c1cccc(N=C(O)c2cnc(=NC(C)C)[nH]c2)c1', '*n1...
# 9996  ['*OC', '*c1ccc(*)nc1', '*C(*)n1ccnc1', '*C1CC...
# 9997  ['*C1CCN(S(=O)(=O)N(C)C)CC1', '*c1ncn(*)n1', '...
# 9998  ['*OC', '*CCCN=C(O)[C@@H](*)C', '*O*', '*C(*)=...
# 9999  ['*[C@H](N)[C@H](C)CC', '*c1cn(CC)c(*)n1', '*c...
#
# [10000 rows x 1 columns]

# %%
import numpy as np
import ast

num_frag = []
for i in df['SMILES']:
    # 转换为列表
    list_data = ast.literal_eval(i)
    num_frag.append(len(list_data))

np.mean(num_frag)
# Out:
# 4.1297

# %%
np.var(num_frag, ddof=1)
# Out:
# 3.26080399039904

# %%
num_frag
# Out:
# [2,
#  4,
#  4,
#  2,
#  3,
#  5,
#  2,
#  5,
#  4,
#  5,
#  3,
#  3,
#  4,
#  3,
#  2,
#  6,
#  3,
#  2,
#  6,
#  2,
#  2,
#  4,
#  2,
#  2,
#  3,
#  6,
#  2,
#  4,
#  3,
#  7,
#  2,
#  3,
#  4,
#  4,
#  4,
#  4,
#  5,
#  2,
#  2,
#  4,
#  3,
#  5,
#  6,
#  4,
#  4,
#  3,
#  5,
#  4,
#  5,
#  8,
#  2,
#  2,
#  4,
#  3,
#  5,
#  7,
#  4,
#  5,
#  6,
#  3,
#  4,
#  10,
#  3,
#  3,
#  2,
#  4,
#  7,
#  2,
#  3,
#  2,
#  6,
#  5,
#  6,
#  2,
#  5,
#  4,
#  2,
#  3,
#  4,
#  4,
#  2,
#  5,
#  2,
#  3,
#  3,
#  4,
#  7,
#  3,
#  4,
#  9,
#  7,
#  5,
#  4,
#  2,
#  5,
#  8,
#  7,
#  4,
#  3,
#  5,
#  2,
#  4,
#  2,
#  4,
#  3,
#  2,
#  4,
#  3,
#  4,
#  2,
#  2,
#  6,
#  5,
#  2,
#  3,
#  5,
#  2,
#  6,
#  3,
#  4,
#  2,
#  2,
#  2,
#  5,
#  7,
#  4,
#  5,
#  3,
#  3,
#  8,
#  5,
#  5,
#  3,
#  3,
#  2,
#  8,
#  4,
#  4,
#  4,
#  9,
#  6,
#  6,
#  3,
#  3,
#  9,
#  7,
#  3,
#  4,
#  4,
#  2,
#  4,
#  4,
#  2,
#  4,
#  3,
#  3,
#  2,
#  3,
#  7,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  2,
#  8,
#  3,
#  4,
#  8,
#  7,
#  8,
#  3,
#  4,
#  3,
#  3,
#  4,
#  8,
#  8,
#  7,
#  2,
#  6,
#  2,
#  4,
#  2,
#  6,
#  4,
#  4,
#  8,
#  5,
#  3,
#  3,
#  5,
#  6,
#  8,
#  4,
#  3,
#  5,
#  4,
#  8,
#  4,
#  3,
#  4,
#  4,
#  3,
#  5,
#  3,
#  4,
#  4,
#  2,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  4,
#  7,
#  4,
#  5,
#  3,
#  3,
#  3,
#  5,
#  4,
#  3,
#  6,
#  4,
#  7,
#  3,
#  4,
#  3,
#  2,
#  8,
#  5,
#  2,
#  2,
#  6,
#  6,
#  10,
#  5,
#  6,
#  5,
#  2,
#  2,
#  4,
#  4,
#  3,
#  3,
#  3,
#  6,
#  2,
#  4,
#  3,
#  7,
#  6,
#  3,
#  3,
#  2,
#  5,
#  5,
#  5,
#  6,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  6,
#  5,
#  2,
#  6,
#  3,
#  2,
#  8,
#  5,
#  4,
#  2,
#  4,
#  4,
#  2,
#  3,
#  6,
#  4,
#  6,
#  4,
#  5,
#  5,
#  5,
#  4,
#  4,
#  5,
#  2,
#  2,
#  11,
#  7,
#  3,
#  4,
#  3,
#  5,
#  6,
#  6,
#  4,
#  2,
#  2,
#  4,
#  3,
#  4,
#  5,
#  3,
#  5,
#  7,
#  4,
#  8,
#  3,
#  6,
#  4,
#  3,
#  6,
#  2,
#  3,
#  7,
#  4,
#  6,
#  4,
#  2,
#  4,
#  7,
#  7,
#  6,
#  5,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  5,
#  3,
#  5,
#  6,
#  4,
#  7,
#  4,
#  6,
#  3,
#  8,
#  3,
#  4,
#  7,
#  5,
#  7,
#  4,
#  6,
#  7,
#  5,
#  2,
#  4,
#  6,
#  4,
#  4,
#  3,
#  7,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  4,
#  4,
#  8,
#  3,
#  4,
#  2,
#  4,
#  3,
#  8,
#  5,
#  5,
#  3,
#  2,
#  4,
#  4,
#  5,
#  4,
#  4,
#  4,
#  6,
#  6,
#  2,
#  5,
#  3,
#  6,
#  3,
#  2,
#  4,
#  4,
#  4,
#  5,
#  3,
#  2,
#  3,
#  4,
#  5,
#  7,
#  6,
#  3,
#  3,
#  2,
#  3,
#  7,
#  5,
#  7,
#  7,
#  5,
#  8,
#  3,
#  4,
#  8,
#  4,
#  3,
#  5,
#  2,
#  3,
#  2,
#  2,
#  6,
#  2,
#  3,
#  4,
#  3,
#  4,
#  2,
#  3,
#  6,
#  5,
#  5,
#  4,
#  2,
#  2,
#  3,
#  3,
#  5,
#  3,
#  6,
#  6,
#  5,
#  13,
#  3,
#  4,
#  2,
#  3,
#  3,
#  6,
#  2,
#  3,
#  3,
#  5,
#  4,
#  2,
#  2,
#  2,
#  4,
#  3,
#  9,
#  2,
#  4,
#  4,
#  5,
#  4,
#  4,
#  4,
#  3,
#  2,
#  3,
#  5,
#  5,
#  3,
#  5,
#  4,
#  3,
#  3,
#  2,
#  7,
#  5,
#  4,
#  5,
#  2,
#  2,
#  5,
#  3,
#  9,
#  3,
#  5,
#  4,
#  10,
#  4,
#  4,
#  6,
#  2,
#  3,
#  2,
#  3,
#  5,
#  2,
#  7,
#  5,
#  4,
#  6,
#  6,
#  2,
#  2,
#  5,
#  4,
#  2,
#  4,
#  5,
#  3,
#  2,
#  2,
#  2,
#  8,
#  3,
#  5,
#  6,
#  6,
#  4,
#  6,
#  7,
#  6,
#  3,
#  4,
#  3,
#  5,
#  7,
#  2,
#  2,
#  7,
#  4,
#  6,
#  4,
#  5,
#  6,
#  2,
#  2,
#  6,
#  2,
#  6,
#  3,
#  4,
#  7,
#  7,
#  5,
#  4,
#  3,
#  2,
#  5,
#  5,
#  2,
#  6,
#  5,
#  4,
#  3,
#  4,
#  6,
#  4,
#  6,
#  2,
#  6,
#  4,
#  3,
#  6,
#  2,
#  5,
#  4,
#  4,
#  6,
#  2,
#  3,
#  3,
#  6,
#  2,
#  4,
#  4,
#  4,
#  3,
#  4,
#  7,
#  3,
#  8,
#  3,
#  9,
#  3,
#  5,
#  5,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  5,
#  3,
#  3,
#  4,
#  11,
#  4,
#  5,
#  2,
#  2,
#  6,
#  4,
#  3,
#  3,
#  4,
#  6,
#  3,
#  4,
#  2,
#  8,
#  5,
#  5,
#  2,
#  3,
#  2,
#  5,
#  8,
#  3,
#  4,
#  6,
#  3,
#  2,
#  4,
#  5,
#  3,
#  6,
#  6,
#  2,
#  2,
#  3,
#  4,
#  2,
#  4,
#  4,
#  3,
#  4,
#  4,
#  3,
#  2,
#  7,
#  2,
#  5,
#  5,
#  3,
#  3,
#  2,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  8,
#  2,
#  8,
#  4,
#  3,
#  4,
#  2,
#  2,
#  6,
#  4,
#  4,
#  5,
#  3,
#  3,
#  2,
#  2,
#  4,
#  5,
#  7,
#  4,
#  4,
#  3,
#  5,
#  6,
#  2,
#  3,
#  4,
#  7,
#  2,
#  5,
#  2,
#  2,
#  5,
#  3,
#  6,
#  7,
#  4,
#  6,
#  3,
#  3,
#  3,
#  6,
#  2,
#  4,
#  3,
#  6,
#  5,
#  6,
#  8,
#  3,
#  5,
#  6,
#  2,
#  2,
#  4,
#  5,
#  7,
#  5,
#  4,
#  3,
#  3,
#  2,
#  4,
#  6,
#  2,
#  4,
#  5,
#  5,
#  2,
#  6,
#  5,
#  7,
#  2,
#  6,
#  4,
#  5,
#  4,
#  4,
#  3,
#  4,
#  3,
#  3,
#  2,
#  3,
#  7,
#  3,
#  5,
#  3,
#  2,
#  9,
#  4,
#  2,
#  4,
#  4,
#  2,
#  3,
#  5,
#  6,
#  3,
#  4,
#  9,
#  5,
#  2,
#  6,
#  3,
#  5,
#  4,
#  4,
#  5,
#  4,
#  6,
#  5,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  2,
#  5,
#  8,
#  6,
#  5,
#  5,
#  5,
#  3,
#  4,
#  6,
#  2,
#  3,
#  4,
#  2,
#  5,
#  4,
#  2,
#  2,
#  2,
#  5,
#  2,
#  3,
#  3,
#  2,
#  7,
#  5,
#  4,
#  2,
#  6,
#  3,
#  3,
#  7,
#  4,
#  3,
#  6,
#  2,
#  2,
#  4,
#  3,
#  7,
#  8,
#  5,
#  3,
#  6,
#  2,
#  4,
#  6,
#  6,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  2,
#  4,
#  3,
#  3,
#  2,
#  4,
#  5,
#  3,
#  6,
#  3,
#  6,
#  4,
#  3,
#  3,
#  4,
#  6,
#  2,
#  5,
#  3,
#  5,
#  5,
#  4,
#  2,
#  4,
#  2,
#  7,
#  5,
#  7,
#  9,
#  4,
#  5,
#  4,
#  4,
#  5,
#  4,
#  4,
#  3,
#  2,
#  8,
#  4,
#  5,
#  17,
#  4,
#  5,
#  6,
#  6,
#  2,
#  2,
#  2,
#  5,
#  5,
#  6,
#  4,
#  2,
#  4,
#  5,
#  9,
#  6,
#  3,
#  4,
#  2,
#  2,
#  4,
#  2,
#  5,
#  4,
#  2,
#  2,
#  4,
#  4,
#  5,
#  3,
#  2,
#  5,
#  7,
#  3,
#  3,
#  2,
#  5,
#  3,
#  4,
#  3,
#  4,
#  3,
#  5,
#  3,
#  4,
#  8,
#  2,
#  4,
#  3,
#  3,
#  2,
#  8,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  4,
#  4,
#  3,
#  3,
#  2,
#  5,
#  4,
#  2,
#  5,
#  4,
#  4,
#  2,
#  5,
#  4,
#  5,
#  4,
#  6,
#  6,
#  6,
#  3,
#  6,
#  4,
#  5,
#  2,
#  6,
#  3,
#  3,
#  7,
#  4,
#  2,
#  2,
#  3,
#  5,
#  2,
#  7,
#  4,
#  4,
#  5,
#  6,
#  4,
#  2,
#  3,
#  4,
#  5,
#  3,
#  3,
#  8,
#  7,
#  ...]

# %%
from tdc import Oracle
from tqdm import tqdm

def cal_QED(smiles):
    oracle = Oracle(name='QED')
    return oracle(smiles)


def cal_DRD2(smiles):
    oracle = Oracle(name='DRD2')
    return oracle(smiles)


def cal_GSK3b(smiles):
    oracle = Oracle(name='GSK3b')
    return oracle(smiles)


def cal_JNK3(smiles):
    oracle = Oracle(name='JNK3')
    return oracle(smiles)


def cal_Albuterol_Similarity(smiles):
    oracle = Oracle(name='Albuterol_Similarity')
    return oracle(smiles)


def cal_Amlodipine_MPO(smiles):
    oracle = Oracle(name='Amlodipine_MPO')
    return oracle(smiles)


def cal_Celecoxib_Rediscovery(smiles):
    oracle = Oracle(name='Celecoxib_Rediscovery')
    return oracle(smiles)


def cal_Deco_Hop(smiles):
    oracle = Oracle(name='Deco_Hop')
    return oracle(smiles)


def cal_Fexofenadine_MPO(smiles):
    oracle = Oracle(name='Fexofenadine_MPO')
    return oracle(smiles)


def cal_Isomers_C7H8N2O2(smiles):
    oracle = Oracle(name='Isomers_C7H8N2O2')
    return oracle(smiles)


def cal_Isomers_C9H10N2O2PF2Cl(smiles):
    oracle = Oracle(name='Isomers_C9H10N2O2PF2Cl')
    return oracle(smiles)


def cal_Median1(smiles):
    oracle = Oracle(name='Median1')
    return oracle(smiles)


def cal_Median2(smiles):
    oracle = Oracle(name='Median2')
    return oracle(smiles)


def cal_Mestranol_Similarity(smiles):
    oracle = Oracle(name='Mestranol_Similarity')
    return oracle(smiles)


def cal_Osimertinib_MPO(smiles):
    oracle = Oracle(name='Osimertinib_MPO')
    return oracle(smiles)


def cal_Perindopril_MPO(smiles):
    oracle = Oracle(name='Perindopril_MPO')
    return oracle(smiles)


def cal_Ranolazine_MPO(smiles):
    oracle = Oracle(name='Ranolazine_MPO')
    return oracle(smiles)


def cal_Scaffold_Hop(smiles):
    oracle = Oracle(name='Scaffold_Hop')
    return oracle(smiles)


def cal_Sitagliptin_MPO(smiles):
    oracle = Oracle(name='Sitagliptin_MPO')
    return oracle(smiles)


def cal_Thiothixene_Rediscovery(smiles):
    oracle = Oracle(name='Thiothixene_Rediscovery')
    return oracle(smiles)


def cal_Troglitazone_Rediscovery(smiles):
    oracle = Oracle(name='Troglitazone_Rediscovery')
    return oracle(smiles)


def cal_Valsartan_SMARTS(smiles):
    oracle = Oracle(name='Valsartan_SMARTS')
    return oracle(smiles)


def cal_Zaleplon_MPO(smiles):
    oracle = Oracle(name='Zaleplon_MPO')
    return oracle(smiles)


def cal_all_metrics(smiles):
    """
    Calculates the 23 metrics based on the provided SMILES string and scoring functions described in the images.

    Args:
        smiles (str): SMILES string of the molecule.

    Returns:
        dict: A dictionary containing the calculated values for each metric. Returns None if the input SMILES is invalid.
    """
    results = {}

    list = ['QED', 'DRD2', 'GSK3b', 'JNK3', 'Albuterol_Similarity', 'Amlodipine_MPO', 'Celecoxib_Rediscovery',
            'Deco_Hop',
            'Fexofenadine_MPO', 'Isomers_C7H8N2O2', 'Isomers_C9H10N2O2PF2Cl', 'Median1', 'Median2',
            'Mestranol_Similarity',
            'Osimertinib_MPO', 'Perindopril_MPO', 'Ranolazine_MPO', 'Scaffold_Hop', 'Sitagliptin_MPO',
            'Thiothixene_Rediscovery',
            'Troglitazone_Rediscovery', 'Valsartan_SMARTS', 'Zaleplon_MPO']

    for i in tqdm(list):
        results[i] = globals()[f'cal_{i}'](smiles)

    return results

# %%
# Example usage:
results = cal_all_metrics(large_results)
# Out:
#   0%|                                                                                                                                                                                    | 0/23 [00:02<?, ?it/s]
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fe96cc1b520>>
# Traceback (most recent call last):
#   File "/home/yzf/anaconda3/envs/fragpt/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
import statistics
data = results
# 计算每个列表的均值
for key, values in data.items():
    mean_value = statistics.mean(values)
    print(f"Mean of {key}: {mean_value}")

# %%
# 计算每个列表的 Top 10 均值
for key, values in data.items():
    # 对列表进行降序排序，并取前 10 个值
    top_10 = sorted(values, reverse=True)[:10]
    # 计算均值
    mean_top_10 = sum(top_10) / len(top_10)
    print(f"Top 10 mean of {key}: {mean_top_10}")
